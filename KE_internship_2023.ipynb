# %% [markdown]
# ### 1. Импорты и настройка окружения

# %%
# Installations

# ! pip install transformers sentencepiece catboost torch scikit-learn pandas scikit-learn pyarrow fastparquet ipywidgets widgetsnbextension

# %%
import zipfile
import pandas as pd
import json

import torch
from transformers import AutoTokenizer, AutoModel

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score
from sklearn import preprocessing

from catboost import Pool, cv

from statistics import mean

# %%
# Extention for CatBoost visualisation

# ! jupyter nbextension enable --py widgetsnbextension

# %% [markdown]
# ### 2. Исследовательский анализ данных

# %% [markdown]
# Распаковка архива

# %%
# archive_path = 'internship_2023.zip'
# directory_to_extract_to = 'KE_internship_2023'
# 
# with zipfile.ZipFile(archive_path, 'r') as zip_ref:
#     zip_ref.extractall(directory_to_extract_to)

# %% [markdown]
# **Описание датасета**

# %%
df = pd.read_parquet('KE_internship_2023/train.parquet')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91120 entries, 0 to 99992
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     91120 non-null  int64
#  1   category_id    91120 non-null  int64
#  2   sale           91120 non-null  bool
#  3   shop_id        91120 non-null  int64
#  4   shop_title     91120 non-null  object
#  5   rating         91120 non-null  float64
#  6   text_fields    91120 non-null  object
#  7   category_name  91120 non-null  object
# dtypes: bool(1), float64(1), int64(3), object(3)
# memory usage: 5.6+ MB

# %% [markdown]
# Было решено использовать только табличные данные. На это есть ряд причин:
#
# 1) Теоретически, возможны случаи того, что товар со схожим описанием может иметь довольно разный внешний вид, мы от этого не застрахованы. Тогда CNN может неправильно классифицировать такие вещи. Отсутствие таких случаев в тренировочном датасете негативно скажется на точности предсказаний. Следовательно -хорошая текстовая модель будет более робастной.
# 2) Также Object Classification модель будет плохо определять редкие классы в нашем случае, ведь наш тренировочный датасет сильно несбалансирован (показано дальше).
# 3) В телеграм-чат стажировки скинули репозиторий о классификации продуктов маркетплейса при помощи мультимодального подхода (с использованием как текста, так и картинок) - https://github.com/1sh1vam/E-commerce-products-classification-using-images-and-text?ysclid=lf9m2l93ft95384990. После этой публикации было решено отказаться от фьюза текста и изображений.
# 4) **Личная причина** - На своём текущем месте работы я решал Computer Vision задачи (такие как Object Detection), поэтому решение NLP-задачи мне кажется более интересным.

# %% [markdown]
# Давайте посмотрим на изначальные фичи и поправим индексацию, для удобства (отсутсвует индекс 2).

# %%
# Важные фичи - shop_id, что-то из text_fields

df.head()
# Out:
#    product_id  category_id   sale  shop_id           shop_title  rating  \
# 0      325286        12171  False     9031                Aksik     5.0
# 1      888134        14233  False    18305                 Sela     5.0
# 3     1267173        13429  False    16357  ЮНЛАНДИЯ канцтовары     5.0
# 4     1416943         2789  False    34666        вася-nicotine     4.0
# 5     1058275        12834  False    26389           Lim Market     4.6
#
#                                          text_fields  \
# 0  {"title": "Зарядный кабель Borofone BX1 Lightn...
# 1  {"title": "Трусы Sela", "description": "Трусы-...
# 3  {"title": "Гуашь \"ЮНЫЙ ВОЛШЕБНИК\", 12 цветов...
# 4  {"title": "Колба для кальяна Крафт (разные цве...
# 5  {"title": "Пижама женская, однотонная с шортам...
#
#                                        category_name
# 0  Все категории->Электроника->Смартфоны и телефо...
# 1  Все категории->Одежда->Женская одежда->Белье и...
# 3  Все категории->Хобби и творчество->Рисование->...
# 4  Все категории->Хобби и творчество->Товары для ...
# 5  Все категории->Одежда->Женская одежда->Домашня...

# %%
df = df.reindex(range(len(df)),method='ffill')
df.head()
# Out:
#    product_id  category_id   sale  shop_id           shop_title  rating  \
# 0      325286        12171  False     9031                Aksik     5.0
# 1      888134        14233  False    18305                 Sela     5.0
# 2      888134        14233  False    18305                 Sela     5.0
# 3     1267173        13429  False    16357  ЮНЛАНДИЯ канцтовары     5.0
# 4     1416943         2789  False    34666        вася-nicotine     4.0
#
#                                          text_fields  \
# 0  {"title": "Зарядный кабель Borofone BX1 Lightn...
# 1  {"title": "Трусы Sela", "description": "Трусы-...
# 2  {"title": "Трусы Sela", "description": "Трусы-...
# 3  {"title": "Гуашь \"ЮНЫЙ ВОЛШЕБНИК\", 12 цветов...
# 4  {"title": "Колба для кальяна Крафт (разные цве...
#
#                                        category_name
# 0  Все категории->Электроника->Смартфоны и телефо...
# 1  Все категории->Одежда->Женская одежда->Белье и...
# 2  Все категории->Одежда->Женская одежда->Белье и...
# 3  Все категории->Хобби и творчество->Рисование->...
# 4  Все категории->Хобби и творчество->Товары для ...

# %% [markdown]
# В нашем датасете присутсвует 874 класса.

# %%
df['category_id'].nunique()
# Out:
# 874

# %%
occur = df['category_id'].value_counts()
occur
# Out:
# 11937    6646
# 14922    3741
# 13143    1455
# 13651    1450
# 12604    1231
#          ...
# 14033       1
# 12836       1
# 11549       1
# 11875       1
# 12808       1
# Name: category_id, Length: 874, dtype: int64

# %% [markdown]
# Я пошёл по лёгкому пути - выбросил строчки из классов, которые встречаются < 10 раз. Ведь должно быть так, чтобы каждый класс попал в тренировочный и тестовый датасет или в каждый фолд кросс-валидации. Более корректной была бы генерация новый данных для редких классов.

# %%
rare_labels = occur[occur < 10].index
indexes_to_drop = df[df['category_id'].isin(rare_labels)].index
indexes_to_drop
# Out:
# Int64Index([  134,   229,   405,   455,   491,   524,   529,   776,   817,
#              1203,
#             ...
#             90219, 90686, 90692, 90719, 90856, 90964, 91002, 91027, 91046,
#             91071],
#            dtype='int64', length=883)

# %%
df.drop(indexes_to_drop, inplace=True)
# reindexing
df = df.reindex(range(len(df)),method='ffill')
df['category_id'].nunique()
# Out:
# 728

# %% [markdown]
# У нас осталось 728 уникальных классов

# %% [markdown]
# ### 3. Обработка данных

# %% [markdown]
# Наиболее значимые фичи - shoз_title и поле **title** в text_fields. Было решено в дальнейшем использовать только их.

# %%
# Retrieving info from text_fields

def parse_text(df: pd.DataFrame):
  product_title = []
  shop_title = []
  
  for index, row in df.iterrows():
    # processing json
    json_dict = json.loads(row['text_fields'].lower())
    title_value = json_dict['title']
    product_title.append(title_value)
    # processing shop_title
    shop_title.append(row['shop_title'].lower())

  product_title = pd.Series(product_title)
  shop_title = pd.Series(shop_title)
  return product_title, shop_title

product_title, shop_title = parse_text(df)
product_title.head()
# Out:
# 0    зарядный кабель borofone bx1 lightning для айф...
# 1                                           трусы sela
# 2                                           трусы sela
# 3    гуашь "юный волшебник", 12 цветов по 35 мл, бо...
# 4               колба для кальяна крафт (разные цвета)
# dtype: object

# %%
shop_title.head()
# Out:
# 0                  aksik
# 1                   sela
# 2                   sela
# 3    юнландия канцтовары
# 4          вася-nicotine
# dtype: object

# %% [markdown]
# Кодировка категорий.
# * LabelEncoding был использован для упорядочивания ID категорий (от 0 до 727).
# * categ_dict - словарь, мапящий новый category_id к category_name. Нужен для визуальной проверки работы модели.
# * new_to_old_dict - словарь, мапящий новый category_id к старому category_id.

# %%
old_categs = df['category_id'].unique()
category_name = df['category_name'].unique()

df['category_id'] = preprocessing.LabelEncoder().fit_transform(df['category_id'])
new_categs = df['category_id'].unique()

categ_dict = {k:v for k,v in zip(new_categs, category_name)}
new_to_old_dict = {k:v for k,v in zip(new_categs, old_categs)}

# %%
df = df.drop(['product_id', 'sale', 'shop_id', 'rating', 'text_fields', 'category_name'], axis = 1)

df['shop_title'] = shop_title
df['product_title'] = product_title

df.tail(5)
# Out:
#        category_id       shop_title  \
# 90232          360           el'kar
# 90233          689  iservice.market
# 90234          102          pigtail
# 90235          168           o2body
# 90236           46            vazan
#
#                                            product_title
# 90232  мантоварка/пароварка алюминиевая 6 л с 3 сетка...
# 90233     стекло ceramics матовое для tecno camon 15 air
# 90234            кронштейн для тв uniteki fm1625 32"-55"
# 90235         грабер щипцы для захвата и чистки раковины
# 90236            набор для творчества "эпоксидная смола"

# %% [markdown]
# Как мы видим, пустых строчек нет.

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### 4. Реализация простого бейзлайна

# %% [markdown]
# Для начала было решено сделать простейшее решение. Выбор пал на метод, описанный в этой статье - https://towardsdatascience.com/classifying-marketplace-inventory-at-scale-with-machine-learning-99e69eac585e

# %% [markdown]
# В бейзлайне:
#
# 1) Через CountVectorize формируется словарь (Bag of Words). Он просто:
#     * Токенизирует строки.
#     * Считает количество каждого токена в корпусе.
# 2) Через этот словарь создаёт sparce-вектора строк. Например:
#     * Слово "кальян" будет иметь вектор (0, 322), что значит - вектор, где все элементы равны 0, кроме 322 (1). Этот вектор sparce, так как он почти полностью состоит из 0.
# 3) Классификация через Naive Bayes.

# %%
df_copy = df 
df_copy = df_copy.drop(['shop_title'], axis = 1)

vocabulary = CountVectorizer()
# К сожалению, не получилось обучить на 2 столбцах
vocabulary.fit(df_copy['product_title'])
print(f'Размер словаря: {len(vocabulary.vocabulary_)}')
# Out:
# Размер словаря: 38847

# %%
counts = vocabulary.transform(df_copy['product_title'])
counts
# Out:
# <90237x38847 sparse matrix of type '<class 'numpy.int64'>'
# 	with 584274 stored elements in Compressed Sparse Row format>

# %%
n_train = int(.8 * df_copy.shape[0])


x_train = counts[:n_train]
y_train = df_copy['category_id'][:n_train]

x_test = counts[n_train:]
y_test = df_copy['category_id'][n_train:]

x_train
# Out:
# <72189x38847 sparse matrix of type '<class 'numpy.int64'>'
# 	with 467768 stored elements in Compressed Sparse Row format>

# %%
nb = MultinomialNB()

nb.fit(x_train, y_train)
predictions = nb.predict(x_test)

f1_Bayes = f1_score(y_test, predictions, average='weighted')
print(f1_Bayes)
# Out:
# 0.645030911730545

# %% [markdown]
# Weighter f1 получился = 0.665

# %% [markdown]
# **Описать, почему данный метод не очень**

# %% [markdown]
# ### 5. Генерация эмбеддингов

# %% [markdown]
# Для векторизации текста было решено использовать dense векторное представление текста:
# 1) чтобы не генерировать вектора очень большой размерности (как, например, через CountVectorizer).
# 2) SOTA методы генерируют именно dense эмбеддинги.
#
# Был использован претренированный rubert-tiny2 от Сбера, так как:
# 1) Он знает как русский, так английский язык.
# 2) Эмбеддинг сайз = 312, а эти минимальный размер эмбеддинга среди Бертов. Это уменьшит вычислительную нагрузку.
# 3) Энкодер РуБерта - это трансформер, а за счёт self-attention он понимает контекст и берёт во внимание порядок слов.
# 4) Также он может векторизовать как 1 слово, так и предложение. Для колонки 'shop_title' это не важно, но для 'product_title' - это очень важно.

# %%
tokenizer = AutoTokenizer.from_pretrained("cointegrated/rubert-tiny2")
model = AutoModel.from_pretrained("cointegrated/rubert-tiny2")
model.cuda()
# Out:
# Some weights of the model checkpoint at cointegrated/rubert-tiny2 were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(83828, 312, padding_idx=0)
#     (position_embeddings): Embedding(2048, 312)
#     (token_type_embeddings): Embedding(2, 312)
#     (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-2): 3 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=312, out_features=312, bias=True)
#             (key): Linear(in_features=312, out_features=312, bias=True)
#             (value): Linear(in_features=312, out_features=312, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=312, out_features=312, bias=True)
#             (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=312, out_features=600, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=600, out_features=312, bias=True)
#           (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=312, out_features=312, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def embed_bert_cls(text, model, tokenizer):
    t = tokenizer(text, padding=True, truncation=True, return_tensors='pt')
    with torch.no_grad():
        model_output = model(**{k: v.to(model.device) for k, v in t.items()})
    embeddings = model_output.last_hidden_state[:, 0, :]
    embeddings = torch.nn.functional.normalize(embeddings)
    return embeddings[0].cpu().numpy()

# %%
embedding_size = embed_bert_cls('привет мир', model, tokenizer).shape[0]
embedding_size
# Out:
# 312

# %%
def text2colums(features):
  # Создание пустых Датафреймов
  product_title = pd.DataFrame(index=features.index, columns = range(embedding_size))
  shop_title = pd.DataFrame(index=features.index, columns = range(embedding_size, 2*embedding_size))

  for i in range(len(features)):
    product_title.loc[features.index[i], :] = embed_bert_cls(features['product_title'][i], model, tokenizer)
    shop_title.loc[features.index[i], :] = embed_bert_cls(features['shop_title'][i], model, tokenizer)
  return product_title, shop_title

# %%
product_title, shop_title = text2colums(df)

product_title = pd.DataFrame(product_title, index=df.index, columns = range(embedding_size))
product_title.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.041848  0.076797  0.100111  -0.09684   -0.0175  0.031053 -0.038998
# 1  0.077617 -0.029442  0.000839 -0.048024  0.010647 -0.006344  0.080962
# 2  0.077617 -0.029442  0.000839 -0.048024  0.010647 -0.006344  0.080962
# 3  0.105562  0.031073 -0.032013 -0.114572 -0.030688  0.040483 -0.060621
# 4  0.067184 -0.078257 -0.002021 -0.032678    0.0144  0.027183  0.003262
#
#         7         8         9    ...       302       303       304       305  \
# 0 -0.040375  -0.03768 -0.041215  ...   0.03641  0.004447  0.028502 -0.038608
# 1  0.033694 -0.016182  -0.03961  ...  0.061222  0.007703  0.014565  0.036552
# 2  0.033694 -0.016182  -0.03961  ...  0.061222  0.007703  0.014565  0.036552
# 3  0.031279 -0.055251 -0.003542  ...  0.069968 -0.028857  0.020296 -0.017557
# 4  0.048267 -0.109209 -0.060674  ...  0.051381  0.032925  0.010762 -0.042912
#
#         306       307       308       309       310       311
# 0 -0.023932 -0.012764  0.007445  0.045618  0.045941 -0.062663
# 1  0.032607 -0.001435  -0.00623  0.016611  0.037598 -0.102271
# 2  0.032607 -0.001435  -0.00623  0.016611  0.037598 -0.102271
# 3  0.027912  0.017539 -0.010598     0.016  0.048476 -0.021955
# 4   0.01832  0.020478 -0.047669  0.038493  0.097577 -0.125223
#
# [5 rows x 312 columns]

# %%
shop_title.head()
# Out:
#         312       313       314       315       316       317       318  \
# 0  0.026618 -0.046738   0.01004 -0.038673  0.039722  0.017055  0.086188
# 1  0.047774 -0.007012  0.010186 -0.057968 -0.007213 -0.015189  0.058021
# 2  0.047774 -0.007012  0.010186 -0.057968 -0.007213 -0.015189  0.058021
# 3  0.081229 -0.025745  0.043016 -0.036166  0.015317 -0.003419   0.06258
# 4  0.020314  0.039335  0.009987 -0.093424 -0.006235  0.039141  0.036472
#
#         319       320       321  ...       614       615       616       617  \
# 0  0.022375 -0.002136  0.016785  ...  0.014339  0.006808  0.019619  0.000222
# 1  0.017656 -0.029094 -0.021018  ...  0.049047  0.008838 -0.022514  0.027404
# 2  0.017656 -0.029094 -0.021018  ...  0.049047  0.008838 -0.022514  0.027404
# 3  0.010517  -0.05752 -0.052432  ...  0.030071  0.044538 -0.014533  0.022788
# 4 -0.007236  0.014387 -0.029035  ...  0.027334  0.042659 -0.048443  0.019821
#
#         618       619       620       621       622       623
# 0  0.069489 -0.015718 -0.038993  -0.03254  0.070624 -0.086863
# 1   0.02931 -0.003394   0.00442 -0.039563  0.020289 -0.062201
# 2   0.02931 -0.003394   0.00442 -0.039563  0.020289 -0.062201
# 3  0.060086 -0.014246 -0.027965   0.07792  0.065011 -0.131839
# 4  0.063454 -0.010788 -0.039814  0.023349  0.110247 -0.080109
#
# [5 rows x 312 columns]

# %% [markdown]
# ### 6. Обучение основной модели

# %% [markdown]
# Очень хотелось решить данную задачу без всемогущего чёрного ящика - нейронных сетей. Рассматривались следующие алгоритмы классического машинного обучения с учётом того, что наша задача - мультиклассовая классификация:
#
# 1) KNN - так как планировалось использовать 2 rubert эмбеддинга для тренировки (размерность = 624), то без уменьшения размерности (например, PCA), данная модель бы пострадала бы от Curse of Dimensionality. Но условный PCA не был применён из-за страха того, что он сильно исказит "смысл" эмбеддингов.
#
# 2) K-means для классификации - не использовался из-за Curse of Dimensionality, аналогично с KNN.
#
# 3) Naive Bayes - **интуиция** подсказала, что лучше использовать другой классификатор.
#
# 4) Logistic Regression - хоть это и бинарный классификатор, но переформулировав задачу в One vs one или One vs rest, им можно решить и мультикласс. Но **интуиция** подсказала то, что эта модель не сможет решить такую сложную задачу.
#
# 5) Остались деревья решений и SVM.

# %% [markdown]
# **Выбор остановлен на градиентном бустинге CatBoost**, так как:
#
# 1) Сама библиотека CatBoost очень удобная и позваляет **StraightForward** запустить кросс-валидация и вывести ошибку.
# 2) Градиентный бустинг традиционно хорошо показывает себя на мультиклассовой классификации табличных данных
#
# SVM (есть быть точнее, Support Vector Classifier) тоже можно было использовать ведь это мощная модель. Но в отличии от CatBoost, его нужно было бы дольше тюнить (пробовать One vs One, One vs Rest, возможно помимо линейнего кернела нужно было бы попробовать и другие)

# %%
df_copy = df 
df_copy
# Out:
#        category_id           shop_title  \
# 0              205                aksik
# 1              620                 sela
# 2              620                 sela
# 3              458  юнландия канцтовары
# 4               60        вася-nicotine
# ...            ...                  ...
# 90232          360               el'kar
# 90233          689      iservice.market
# 90234          102              pigtail
# 90235          168               o2body
# 90236           46                vazan
#
#                                            product_title
# 0      зарядный кабель borofone bx1 lightning для айф...
# 1                                             трусы sela
# 2                                             трусы sela
# 3      гуашь "юный волшебник", 12 цветов по 35 мл, бо...
# 4                 колба для кальяна крафт (разные цвета)
# ...                                                  ...
# 90232  мантоварка/пароварка алюминиевая 6 л с 3 сетка...
# 90233     стекло ceramics матовое для tecno camon 15 air
# 90234            кронштейн для тв uniteki fm1625 32"-55"
# 90235         грабер щипцы для захвата и чистки раковины
# 90236            набор для творчества "эпоксидная смола"
#
# [90237 rows x 3 columns]

# %%
df_copy = df_copy.drop(['product_title', 'shop_title'], axis = 1)
df_copy = pd.concat([df_copy, product_title, shop_title], axis=1)

# %%
# Random shuffle 
df_copy = df_copy.sample(frac=1).reset_index(drop=True)
df_copy
# Out:
#        category_id         0         1         2         3         4  \
# 0              451  0.041565 -0.006827  0.021578 -0.059066   0.00019
# 1              604 -0.086439  0.008445   0.02383 -0.126691 -0.011536
# 2              163 -0.022545   0.03679  0.034935 -0.060531 -0.005727
# 3               74  0.048612 -0.043489  0.017148 -0.126079  0.045456
# 4              165  0.046508 -0.035187  0.006396 -0.049864  0.022464
# ...            ...       ...       ...       ...       ...       ...
# 90232          512   0.05115  0.011102    0.0342 -0.001359  0.041342
# 90233          309  0.058573 -0.034381  0.059354 -0.043286  0.010083
# 90234           51  0.048028 -0.068317  0.035106 -0.017742  0.029954
# 90235           51  0.016765 -0.034757   0.07935 -0.068233  0.039645
# 90236          715  0.012938 -0.034147  0.016557 -0.042055  0.044697
#
#               5         6         7         8  ...       614       615  \
# 0       0.05974 -0.000039  0.057721 -0.004248  ...  0.087466  0.077071
# 1      0.043355 -0.008233  0.027485 -0.080029  ...  0.066933 -0.000366
# 2      0.051085 -0.081528    0.0188 -0.049508  ...  0.030189  0.030399
# 3      0.012962 -0.028805  0.009134 -0.061795  ...  0.055504  0.006097
# 4      0.010209  0.029745  0.038138 -0.028309  ... -0.016821  0.023795
# ...         ...       ...       ...       ...  ...       ...       ...
# 90232  -0.01237 -0.027774  0.033896 -0.041717  ...  0.008113  0.036417
# 90233  0.048982 -0.029273  0.043703 -0.074774  ...  0.038842  0.016217
# 90234 -0.009983  0.013147  0.077841  -0.10914  ...  0.039915  0.069705
# 90235 -0.021102 -0.006219  0.019417 -0.063767  ...  0.030172  0.060051
# 90236  0.025506  -0.07461  0.006324 -0.052508  ...  0.026469  0.048097
#
#             616       617       618       619       620       621       622  \
# 0      0.005514 -0.018843  0.035283  0.013954  -0.05117   0.02564  0.058478
# 1     -0.039678 -0.006019  0.028291  0.036701 -0.000778  0.059175  0.011477
# 2     -0.017827 -0.020975  0.040112 -0.011632 -0.036375  0.045179  0.057489
# 3     -0.046257  0.003595  0.054635 -0.019156 -0.010001 -0.006771  0.063839
# 4       0.01829 -0.023281  0.020119 -0.012231 -0.064141  0.053578  0.023031
# ...         ...       ...       ...       ...       ...       ...       ...
# 90232  -0.03205  0.016818  0.007465 -0.016967 -0.037875 -0.040717  0.128553
# 90233  -0.07791 -0.026662  0.071448 -0.032572  0.005547 -0.004953  0.042386
# 90234 -0.039512 -0.020819  0.026866  0.018403 -0.026464  0.029391  0.031261
# 90235 -0.025614 -0.012518  0.058907  0.023986 -0.000153 -0.008302  0.056754
# 90236 -0.016196  -0.01541  0.064205 -0.004291  0.002733   0.01681  0.050435
#
#             623
# 0     -0.099549
# 1      0.009664
# 2     -0.056625
# 3     -0.070384
# 4     -0.119314
# ...         ...
# 90232 -0.076932
# 90233 -0.124937
# 90234 -0.107029
# 90235 -0.075775
# 90236 -0.088392
#
# [90237 rows x 625 columns]

# %% [markdown]
# 5-fold Кросс Валидация градиентного бустинга

# %%
cv_dataset = Pool(data=df_copy.drop(['category_id'], axis=1),
                  label=df_copy['category_id'])

params = {"iterations": 500,
          "learning_rate": 0.3,
          "random_seed": 1,
          "loss_function": 'MultiClass',
          "task_type": "GPU",
          "use_best_model": True}


scores = cv(cv_dataset,
            params,
            iterations = 500,
            fold_count=5, 
            shuffle = False,
            plot=True,
            return_models = True
)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/5]
# 0:	learn: 7.1332965	test: 7.1035587	best: 7.1035587 (0)	total: 2.44s	remaining: 20m 18s
# 1:	learn: 7.6320177	test: 7.6758172	best: 7.1035587 (0)	total: 4.92s	remaining: 20m 24s
# 2:	learn: 7.7554954	test: 7.7935621	best: 7.1035587 (0)	total: 7.3s	remaining: 20m 8s
# 3:	learn: 8.2382416	test: 8.2877906	best: 7.1035587 (0)	total: 9.8s	remaining: 20m 15s
# 4:	learn: 7.9798164	test: 8.0767377	best: 7.1035587 (0)	total: 12.2s	remaining: 20m 8s
# 5:	learn: 7.9256581	test: 7.9745744	best: 7.1035587 (0)	total: 14.7s	remaining: 20m 12s
# 6:	learn: 7.9753225	test: 8.0741964	best: 7.1035587 (0)	total: 17.2s	remaining: 20m 8s
# 7:	learn: 7.6208904	test: 7.7409999	best: 7.1035587 (0)	total: 19.6s	remaining: 20m 2s
# 8:	learn: 7.3374122	test: 7.4838734	best: 7.1035587 (0)	total: 22s	remaining: 19m 59s
# 9:	learn: 7.0266149	test: 7.2064523	best: 7.1035587 (0)	total: 24.5s	remaining: 19m 59s
# 10:	learn: 6.8297577	test: 7.0349210	best: 7.0349210 (10)	total: 26.9s	remaining: 19m 58s
# 11:	learn: 6.5998383	test: 6.8314255	best: 6.8314255 (11)	total: 29.4s	remaining: 19m 56s
# 12:	learn: 6.3852831	test: 6.6461423	best: 6.6461423 (12)	total: 32s	remaining: 19m 57s
# 13:	learn: 6.1962869	test: 6.4779379	best: 6.4779379 (13)	total: 34.4s	remaining: 19m 55s
# 14:	learn: 6.0293908	test: 6.3311832	best: 6.3311832 (14)	total: 36.9s	remaining: 19m 52s
# 15:	learn: 5.8758172	test: 6.1957413	best: 6.1957413 (15)	total: 39.3s	remaining: 19m 49s
# 16:	learn: 5.7601235	test: 6.0945037	best: 6.0945037 (16)	total: 41.7s	remaining: 19m 46s
# 17:	learn: 5.6177702	test: 5.9711678	best: 5.9711678 (17)	total: 44.3s	remaining: 19m 45s
# 18:	learn: 5.5645270	test: 5.9227696	best: 5.9227696 (18)	total: 46.6s	remaining: 19m 38s
# 19:	learn: 5.4351261	test: 5.8129603	best: 5.8129603 (19)	total: 49s	remaining: 19m 36s
# 20:	learn: 5.3295786	test: 5.7216239	best: 5.7216239 (20)	total: 51.4s	remaining: 19m 32s
# 21:	learn: 5.1708287	test: 5.5764652	best: 5.5764652 (21)	total: 53.9s	remaining: 19m 30s
# 22:	learn: 5.0484760	test: 5.4705206	best: 5.4705206 (22)	total: 56.4s	remaining: 19m 29s
# 23:	learn: 4.9488468	test: 5.3879228	best: 5.3879228 (23)	total: 58.9s	remaining: 19m 28s
# 24:	learn: 4.8983182	test: 5.3454043	best: 5.3454043 (24)	total: 1m 1s	remaining: 19m 20s
# 25:	learn: 4.8111012	test: 5.2752259	best: 5.2752259 (25)	total: 1m 3s	remaining: 19m 19s
# 26:	learn: 4.7354526	test: 5.2131105	best: 5.2131105 (26)	total: 1m 5s	remaining: 19m 14s
# 27:	learn: 4.6518796	test: 5.1448538	best: 5.1448538 (27)	total: 1m 8s	remaining: 19m 12s
# 28:	learn: 4.5812209	test: 5.0918283	best: 5.0918283 (28)	total: 1m 10s	remaining: 19m 11s
# 29:	learn: 4.5099349	test: 5.0280010	best: 5.0280010 (29)	total: 1m 13s	remaining: 19m 8s
# 30:	learn: 4.4526368	test: 4.9814198	best: 4.9814198 (30)	total: 1m 15s	remaining: 19m 5s
# 31:	learn: 4.3601544	test: 4.9044377	best: 4.9044377 (31)	total: 1m 18s	remaining: 19m 3s
# 32:	learn: 4.2849140	test: 4.8378307	best: 4.8378307 (32)	total: 1m 20s	remaining: 19m 1s
# 33:	learn: 4.2159102	test: 4.7812866	best: 4.7812866 (33)	total: 1m 23s	remaining: 18m 58s
# 34:	learn: 4.1435296	test: 4.7233850	best: 4.7233850 (34)	total: 1m 25s	remaining: 18m 56s
# 35:	learn: 4.0802824	test: 4.6750073	best: 4.6750073 (35)	total: 1m 28s	remaining: 18m 55s
# 36:	learn: 3.9984069	test: 4.6143464	best: 4.6143464 (36)	total: 1m 30s	remaining: 18m 52s
# 37:	learn: 3.9377939	test: 4.5673739	best: 4.5673739 (37)	total: 1m 33s	remaining: 18m 51s
# 38:	learn: 3.8750726	test: 4.5184780	best: 4.5184780 (38)	total: 1m 35s	remaining: 18m 49s
# 39:	learn: 3.8149760	test: 4.4658255	best: 4.4658255 (39)	total: 1m 37s	remaining: 18m 46s
# 40:	learn: 3.7528807	test: 4.4139837	best: 4.4139837 (40)	total: 1m 40s	remaining: 18m 44s
# 41:	learn: 3.7036136	test: 4.3741232	best: 4.3741232 (41)	total: 1m 42s	remaining: 18m 42s
# 42:	learn: 3.6572276	test: 4.3342491	best: 4.3342491 (42)	total: 1m 45s	remaining: 18m 39s
# 43:	learn: 3.6171025	test: 4.2999652	best: 4.2999652 (43)	total: 1m 47s	remaining: 18m 36s
# 44:	learn: 3.5526699	test: 4.2486140	best: 4.2486140 (44)	total: 1m 50s	remaining: 18m 35s
# 45:	learn: 3.5005842	test: 4.2100701	best: 4.2100701 (45)	total: 1m 52s	remaining: 18m 33s
# 46:	learn: 3.4508744	test: 4.1703697	best: 4.1703697 (46)	total: 1m 55s	remaining: 18m 31s
# 47:	learn: 3.3608462	test: 4.0922290	best: 4.0922290 (47)	total: 1m 57s	remaining: 18m 28s
# 48:	learn: 3.3157382	test: 4.0569201	best: 4.0569201 (48)	total: 2m	remaining: 18m 26s
# 49:	learn: 3.2680858	test: 4.0144489	best: 4.0144489 (49)	total: 2m 2s	remaining: 18m 24s
# 50:	learn: 3.2453471	test: 3.9952117	best: 3.9952117 (50)	total: 2m 5s	remaining: 18m 21s
# 51:	learn: 3.1913207	test: 3.9536547	best: 3.9536547 (51)	total: 2m 7s	remaining: 18m 19s
# 52:	learn: 3.1626878	test: 3.9301346	best: 3.9301346 (52)	total: 2m 9s	remaining: 18m 16s
# 53:	learn: 3.1213929	test: 3.8956348	best: 3.8956348 (53)	total: 2m 12s	remaining: 18m 14s
# 54:	learn: 3.0874420	test: 3.8666778	best: 3.8666778 (54)	total: 2m 14s	remaining: 18m 11s
# 55:	learn: 3.0464855	test: 3.8320191	best: 3.8320191 (55)	total: 2m 17s	remaining: 18m 9s
# 56:	learn: 3.0148765	test: 3.8070231	best: 3.8070231 (56)	total: 2m 19s	remaining: 18m 7s
# 57:	learn: 2.9921688	test: 3.7893435	best: 3.7893435 (57)	total: 2m 22s	remaining: 18m 3s
# 58:	learn: 2.9611312	test: 3.7608899	best: 3.7608899 (58)	total: 2m 24s	remaining: 18m 1s
# 59:	learn: 2.9319246	test: 3.7368034	best: 3.7368034 (59)	total: 2m 27s	remaining: 17m 58s
# 60:	learn: 2.9097956	test: 3.7192533	best: 3.7192533 (60)	total: 2m 29s	remaining: 17m 55s
# 61:	learn: 2.8745008	test: 3.6906374	best: 3.6906374 (61)	total: 2m 32s	remaining: 17m 53s
# 62:	learn: 2.8480182	test: 3.6688053	best: 3.6688053 (62)	total: 2m 34s	remaining: 17m 51s
# 63:	learn: 2.8278914	test: 3.6529801	best: 3.6529801 (63)	total: 2m 36s	remaining: 17m 47s
# 64:	learn: 2.8103763	test: 3.6392977	best: 3.6392977 (64)	total: 2m 39s	remaining: 17m 44s
# 65:	learn: 2.7871703	test: 3.6194226	best: 3.6194226 (65)	total: 2m 41s	remaining: 17m 42s
# 66:	learn: 2.7602411	test: 3.5983748	best: 3.5983748 (66)	total: 2m 44s	remaining: 17m 40s
# 67:	learn: 2.7514169	test: 3.5903950	best: 3.5903950 (67)	total: 2m 46s	remaining: 17m 35s
# 68:	learn: 2.7230793	test: 3.5665808	best: 3.5665808 (68)	total: 2m 48s	remaining: 17m 32s
# 69:	learn: 2.6954266	test: 3.5452079	best: 3.5452079 (69)	total: 2m 51s	remaining: 17m 30s
# 70:	learn: 2.6796442	test: 3.5325896	best: 3.5325896 (70)	total: 2m 53s	remaining: 17m 27s
# 71:	learn: 2.6643124	test: 3.5196550	best: 3.5196550 (71)	total: 2m 55s	remaining: 17m 23s
# 72:	learn: 2.6508874	test: 3.5092343	best: 3.5092343 (72)	total: 2m 57s	remaining: 17m 20s
# 73:	learn: 2.6299577	test: 3.4916689	best: 3.4916689 (73)	total: 3m	remaining: 17m 17s
# 74:	learn: 2.6163957	test: 3.4806731	best: 3.4806731 (74)	total: 3m 2s	remaining: 17m 14s
# 75:	learn: 2.5996755	test: 3.4674021	best: 3.4674021 (75)	total: 3m 4s	remaining: 17m 12s
# 76:	learn: 2.5497887	test: 3.4196420	best: 3.4196420 (76)	total: 3m 7s	remaining: 17m 10s
# 77:	learn: 2.5266497	test: 3.4033087	best: 3.4033087 (77)	total: 3m 10s	remaining: 17m 8s
# 78:	learn: 2.5092105	test: 3.3872779	best: 3.3872779 (78)	total: 3m 12s	remaining: 17m 5s
# 79:	learn: 2.5009917	test: 3.3813155	best: 3.3813155 (79)	total: 3m 14s	remaining: 17m
# 80:	learn: 2.4896728	test: 3.3724687	best: 3.3724687 (80)	total: 3m 16s	remaining: 16m 57s
# 81:	learn: 2.4765579	test: 3.3608294	best: 3.3608294 (81)	total: 3m 18s	remaining: 16m 54s
# 82:	learn: 2.4483101	test: 3.3378160	best: 3.3378160 (82)	total: 3m 21s	remaining: 16m 52s
# 83:	learn: 2.4303484	test: 3.3220100	best: 3.3220100 (83)	total: 3m 23s	remaining: 16m 49s
# 84:	learn: 2.4089799	test: 3.3065849	best: 3.3065849 (84)	total: 3m 26s	remaining: 16m 46s
# 85:	learn: 2.3939254	test: 3.2953574	best: 3.2953574 (85)	total: 3m 28s	remaining: 16m 44s
# 86:	learn: 2.3828751	test: 3.2847036	best: 3.2847036 (86)	total: 3m 30s	remaining: 16m 40s
# 87:	learn: 2.3703662	test: 3.2754156	best: 3.2754156 (87)	total: 3m 33s	remaining: 16m 38s
# 88:	learn: 2.3565962	test: 3.2638538	best: 3.2638538 (88)	total: 3m 35s	remaining: 16m 35s
# 89:	learn: 2.3389297	test: 3.2517514	best: 3.2517514 (89)	total: 3m 38s	remaining: 16m 33s
# 90:	learn: 2.3263241	test: 3.2403062	best: 3.2403062 (90)	total: 3m 40s	remaining: 16m 30s
# 91:	learn: 2.3125719	test: 3.2295439	best: 3.2295439 (91)	total: 3m 42s	remaining: 16m 28s
# 92:	learn: 2.2944357	test: 3.2154761	best: 3.2154761 (92)	total: 3m 45s	remaining: 16m 25s
# 93:	learn: 2.2808829	test: 3.2041499	best: 3.2041499 (93)	total: 3m 47s	remaining: 16m 23s
# 94:	learn: 2.2712497	test: 3.1971695	best: 3.1971695 (94)	total: 3m 50s	remaining: 16m 20s
# 95:	learn: 2.2575534	test: 3.1867919	best: 3.1867919 (95)	total: 3m 52s	remaining: 16m 18s
# 96:	learn: 2.2485840	test: 3.1799711	best: 3.1799711 (96)	total: 3m 54s	remaining: 16m 15s
# 97:	learn: 2.2374178	test: 3.1712175	best: 3.1712175 (97)	total: 3m 57s	remaining: 16m 12s
# 98:	learn: 2.2242467	test: 3.1591756	best: 3.1591756 (98)	total: 3m 59s	remaining: 16m 10s
# 99:	learn: 2.2149990	test: 3.1515451	best: 3.1515451 (99)	total: 4m 1s	remaining: 16m 7s
# 100:	learn: 2.2073022	test: 3.1445694	best: 3.1445694 (100)	total: 4m 3s	remaining: 16m 3s
# 101:	learn: 2.1960532	test: 3.1356086	best: 3.1356086 (101)	total: 4m 6s	remaining: 16m
# 102:	learn: 2.1900764	test: 3.1310234	best: 3.1310234 (102)	total: 4m 8s	remaining: 15m 57s
# 103:	learn: 2.1761974	test: 3.1201993	best: 3.1201993 (103)	total: 4m 10s	remaining: 15m 54s
# 104:	learn: 2.1687439	test: 3.1139930	best: 3.1139930 (104)	total: 4m 13s	remaining: 15m 52s
# 105:	learn: 2.1622440	test: 3.1082894	best: 3.1082894 (105)	total: 4m 15s	remaining: 15m 49s
# 106:	learn: 2.1469000	test: 3.0959792	best: 3.0959792 (106)	total: 4m 17s	remaining: 15m 46s
# 107:	learn: 2.1367578	test: 3.0884622	best: 3.0884622 (107)	total: 4m 20s	remaining: 15m 44s
# 108:	learn: 2.1267664	test: 3.0797759	best: 3.0797759 (108)	total: 4m 22s	remaining: 15m 41s
# 109:	learn: 2.1146995	test: 3.0698115	best: 3.0698115 (109)	total: 4m 24s	remaining: 15m 38s
# 110:	learn: 2.1041639	test: 3.0627610	best: 3.0627610 (110)	total: 4m 27s	remaining: 15m 36s
# 111:	learn: 2.0923514	test: 3.0520757	best: 3.0520757 (111)	total: 4m 29s	remaining: 15m 33s
# 112:	learn: 2.0821435	test: 3.0429958	best: 3.0429958 (112)	total: 4m 31s	remaining: 15m 30s
# 113:	learn: 2.0659910	test: 3.0299828	best: 3.0299828 (113)	total: 4m 34s	remaining: 15m 28s
# 114:	learn: 2.0572680	test: 3.0232593	best: 3.0232593 (114)	total: 4m 36s	remaining: 15m 26s
# 115:	learn: 2.0521606	test: 3.0191476	best: 3.0191476 (115)	total: 4m 38s	remaining: 15m 23s
# 116:	learn: 2.0453729	test: 3.0131431	best: 3.0131431 (116)	total: 4m 41s	remaining: 15m 20s
# 117:	learn: 2.0381355	test: 3.0077644	best: 3.0077644 (117)	total: 4m 43s	remaining: 15m 17s
# 118:	learn: 2.0264214	test: 3.0001284	best: 3.0001284 (118)	total: 4m 45s	remaining: 15m 15s
# 119:	learn: 2.0164231	test: 2.9913989	best: 2.9913989 (119)	total: 4m 48s	remaining: 15m 12s
# 120:	learn: 2.0095737	test: 2.9857165	best: 2.9857165 (120)	total: 4m 50s	remaining: 15m 9s
# 121:	learn: 2.0032163	test: 2.9799810	best: 2.9799810 (121)	total: 4m 52s	remaining: 15m 6s
# 122:	learn: 1.9916765	test: 2.9723026	best: 2.9723026 (122)	total: 4m 55s	remaining: 15m 4s
# 123:	learn: 1.9817925	test: 2.9637845	best: 2.9637845 (123)	total: 4m 57s	remaining: 15m 1s
# 124:	learn: 1.9759672	test: 2.9591936	best: 2.9591936 (124)	total: 4m 59s	remaining: 14m 58s
# 125:	learn: 1.9690999	test: 2.9547793	best: 2.9547793 (125)	total: 5m 1s	remaining: 14m 56s
# 126:	learn: 1.9650158	test: 2.9515260	best: 2.9515260 (126)	total: 5m 4s	remaining: 14m 53s
# 127:	learn: 1.9555549	test: 2.9454973	best: 2.9454973 (127)	total: 5m 6s	remaining: 14m 51s
# 128:	learn: 1.9465746	test: 2.9392557	best: 2.9392557 (128)	total: 5m 8s	remaining: 14m 48s
# 129:	learn: 1.9394744	test: 2.9336133	best: 2.9336133 (129)	total: 5m 11s	remaining: 14m 45s
# 130:	learn: 1.9288651	test: 2.9272469	best: 2.9272469 (130)	total: 5m 13s	remaining: 14m 43s
# 131:	learn: 1.9244453	test: 2.9247916	best: 2.9247916 (131)	total: 5m 15s	remaining: 14m 40s
# 132:	learn: 1.9202658	test: 2.9216097	best: 2.9216097 (132)	total: 5m 17s	remaining: 14m 37s
# 133:	learn: 1.9141164	test: 2.9171748	best: 2.9171748 (133)	total: 5m 20s	remaining: 14m 34s
# 134:	learn: 1.8983749	test: 2.9060130	best: 2.9060130 (134)	total: 5m 22s	remaining: 14m 32s
# 135:	learn: 1.8904933	test: 2.9011508	best: 2.9011508 (135)	total: 5m 25s	remaining: 14m 30s
# 136:	learn: 1.8800209	test: 2.8918424	best: 2.8918424 (136)	total: 5m 27s	remaining: 14m 27s
# 137:	learn: 1.8748205	test: 2.8878853	best: 2.8878853 (137)	total: 5m 29s	remaining: 14m 25s
# 138:	learn: 1.8700917	test: 2.8839418	best: 2.8839418 (138)	total: 5m 31s	remaining: 14m 22s
# 139:	learn: 1.8619625	test: 2.8779618	best: 2.8779618 (139)	total: 5m 34s	remaining: 14m 19s
# 140:	learn: 1.8569644	test: 2.8743476	best: 2.8743476 (140)	total: 5m 36s	remaining: 14m 17s
# 141:	learn: 1.8499520	test: 2.8692989	best: 2.8692989 (141)	total: 5m 38s	remaining: 14m 14s
# 142:	learn: 1.8435177	test: 2.8647682	best: 2.8647682 (142)	total: 5m 41s	remaining: 14m 11s
# 143:	learn: 1.8354296	test: 2.8587859	best: 2.8587859 (143)	total: 5m 43s	remaining: 14m 9s
# 144:	learn: 1.8265758	test: 2.8514407	best: 2.8514407 (144)	total: 5m 45s	remaining: 14m 6s
# 145:	learn: 1.8190719	test: 2.8454007	best: 2.8454007 (145)	total: 5m 48s	remaining: 14m 4s
# 146:	learn: 1.8152325	test: 2.8428347	best: 2.8428347 (146)	total: 5m 50s	remaining: 14m 1s
# 147:	learn: 1.8065081	test: 2.8368585	best: 2.8368585 (147)	total: 5m 52s	remaining: 13m 58s
# 148:	learn: 1.8028658	test: 2.8341067	best: 2.8341067 (148)	total: 5m 54s	remaining: 13m 56s
# 149:	learn: 1.7949847	test: 2.8287893	best: 2.8287893 (149)	total: 5m 57s	remaining: 13m 53s
# 150:	learn: 1.7896286	test: 2.8266265	best: 2.8266265 (150)	total: 5m 59s	remaining: 13m 51s
# 151:	learn: 1.7813273	test: 2.8205005	best: 2.8205005 (151)	total: 6m 2s	remaining: 13m 49s
# 152:	learn: 1.7737813	test: 2.8166894	best: 2.8166894 (152)	total: 6m 4s	remaining: 13m 46s
# 153:	learn: 1.7671738	test: 2.8109094	best: 2.8109094 (153)	total: 6m 6s	remaining: 13m 44s
# 154:	learn: 1.7514261	test: 2.7967202	best: 2.7967202 (154)	total: 6m 9s	remaining: 13m 41s
# 155:	learn: 1.7436354	test: 2.7910937	best: 2.7910937 (155)	total: 6m 11s	remaining: 13m 39s
# 156:	learn: 1.7363191	test: 2.7867665	best: 2.7867665 (156)	total: 6m 13s	remaining: 13m 36s
# 157:	learn: 1.7309634	test: 2.7832993	best: 2.7832993 (157)	total: 6m 16s	remaining: 13m 34s
# 158:	learn: 1.7240374	test: 2.7767648	best: 2.7767648 (158)	total: 6m 18s	remaining: 13m 31s
# 159:	learn: 1.7158817	test: 2.7710712	best: 2.7710712 (159)	total: 6m 20s	remaining: 13m 29s
# 160:	learn: 1.7078395	test: 2.7635545	best: 2.7635545 (160)	total: 6m 23s	remaining: 13m 27s
# 161:	learn: 1.6989665	test: 2.7565915	best: 2.7565915 (161)	total: 6m 25s	remaining: 13m 25s
# 162:	learn: 1.6919337	test: 2.7518082	best: 2.7518082 (162)	total: 6m 28s	remaining: 13m 22s
# 163:	learn: 1.6853620	test: 2.7471698	best: 2.7471698 (163)	total: 6m 30s	remaining: 13m 20s
# 164:	learn: 1.6788740	test: 2.7406920	best: 2.7406920 (164)	total: 6m 32s	remaining: 13m 17s
# 165:	learn: 1.6719475	test: 2.7352518	best: 2.7352518 (165)	total: 6m 35s	remaining: 13m 15s
# 166:	learn: 1.6655759	test: 2.7298434	best: 2.7298434 (166)	total: 6m 37s	remaining: 13m 13s
# 167:	learn: 1.6564689	test: 2.7225762	best: 2.7225762 (167)	total: 6m 40s	remaining: 13m 10s
# 168:	learn: 1.6492358	test: 2.7174249	best: 2.7174249 (168)	total: 6m 42s	remaining: 13m 8s
# 169:	learn: 1.6426319	test: 2.7134036	best: 2.7134036 (169)	total: 6m 44s	remaining: 13m 5s
# 170:	learn: 1.6344526	test: 2.7072158	best: 2.7072158 (170)	total: 6m 47s	remaining: 13m 3s
# 171:	learn: 1.6310361	test: 2.7044497	best: 2.7044497 (171)	total: 6m 49s	remaining: 13m
# 172:	learn: 1.6234169	test: 2.6982777	best: 2.6982777 (172)	total: 6m 51s	remaining: 12m 58s
# 173:	learn: 1.6191143	test: 2.6948675	best: 2.6948675 (173)	total: 6m 53s	remaining: 12m 55s
# 174:	learn: 1.6153573	test: 2.6923109	best: 2.6923109 (174)	total: 6m 56s	remaining: 12m 53s
# 175:	learn: 1.6125071	test: 2.6904839	best: 2.6904839 (175)	total: 6m 58s	remaining: 12m 50s
# 176:	learn: 1.6041639	test: 2.6854158	best: 2.6854158 (176)	total: 7m	remaining: 12m 48s
# 177:	learn: 1.5979052	test: 2.6809239	best: 2.6809239 (177)	total: 7m 3s	remaining: 12m 45s
# 178:	learn: 1.5937948	test: 2.6769718	best: 2.6769718 (178)	total: 7m 5s	remaining: 12m 43s
# 179:	learn: 1.5896699	test: 2.6743392	best: 2.6743392 (179)	total: 7m 7s	remaining: 12m 40s
# 180:	learn: 1.5832959	test: 2.6685919	best: 2.6685919 (180)	total: 7m 10s	remaining: 12m 38s
# 181:	learn: 1.5801495	test: 2.6659693	best: 2.6659693 (181)	total: 7m 12s	remaining: 12m 35s
# 182:	learn: 1.5773632	test: 2.6643746	best: 2.6643746 (182)	total: 7m 14s	remaining: 12m 32s
# 183:	learn: 1.5747895	test: 2.6625381	best: 2.6625381 (183)	total: 7m 16s	remaining: 12m 30s
# 184:	learn: 1.5717474	test: 2.6597245	best: 2.6597245 (184)	total: 7m 19s	remaining: 12m 27s
# 185:	learn: 1.5665517	test: 2.6560073	best: 2.6560073 (185)	total: 7m 21s	remaining: 12m 24s
# 186:	learn: 1.5602633	test: 2.6512820	best: 2.6512820 (186)	total: 7m 23s	remaining: 12m 22s
# 187:	learn: 1.5546945	test: 2.6464025	best: 2.6464025 (187)	total: 7m 26s	remaining: 12m 20s
# 188:	learn: 1.5507205	test: 2.6437118	best: 2.6437118 (188)	total: 7m 28s	remaining: 12m 18s
# 189:	learn: 1.5461269	test: 2.6402401	best: 2.6402401 (189)	total: 7m 30s	remaining: 12m 15s
# 190:	learn: 1.5324213	test: 2.6268436	best: 2.6268436 (190)	total: 7m 33s	remaining: 12m 13s
# 191:	learn: 1.5285744	test: 2.6242512	best: 2.6242512 (191)	total: 7m 35s	remaining: 12m 10s
# 192:	learn: 1.5262413	test: 2.6222215	best: 2.6222215 (192)	total: 7m 37s	remaining: 12m 7s
# 193:	learn: 1.5232543	test: 2.6198118	best: 2.6198118 (193)	total: 7m 39s	remaining: 12m 5s
# 194:	learn: 1.5169981	test: 2.6153965	best: 2.6153965 (194)	total: 7m 42s	remaining: 12m 3s
# 195:	learn: 1.5111291	test: 2.6126002	best: 2.6126002 (195)	total: 7m 44s	remaining: 12m 1s
# 196:	learn: 1.5087081	test: 2.6111743	best: 2.6111743 (196)	total: 7m 47s	remaining: 11m 58s
# 197:	learn: 1.5041766	test: 2.6072421	best: 2.6072421 (197)	total: 7m 49s	remaining: 11m 55s
# 198:	learn: 1.4976592	test: 2.6023002	best: 2.6023002 (198)	total: 7m 51s	remaining: 11m 53s
# 199:	learn: 1.4947353	test: 2.6007279	best: 2.6007279 (199)	total: 7m 54s	remaining: 11m 51s
# 200:	learn: 1.4893509	test: 2.5971804	best: 2.5971804 (200)	total: 7m 56s	remaining: 11m 48s
# 201:	learn: 1.4806633	test: 2.5928509	best: 2.5928509 (201)	total: 7m 59s	remaining: 11m 46s
# 202:	learn: 1.4756819	test: 2.5888625	best: 2.5888625 (202)	total: 8m 1s	remaining: 11m 44s
# 203:	learn: 1.4715028	test: 2.5849783	best: 2.5849783 (203)	total: 8m 4s	remaining: 11m 42s
# 204:	learn: 1.4626170	test: 2.5773641	best: 2.5773641 (204)	total: 8m 6s	remaining: 11m 40s
# 205:	learn: 1.4555012	test: 2.5724407	best: 2.5724407 (205)	total: 8m 8s	remaining: 11m 37s
# 206:	learn: 1.4504351	test: 2.5693704	best: 2.5693704 (206)	total: 8m 11s	remaining: 11m 35s
# 207:	learn: 1.4416718	test: 2.5636672	best: 2.5636672 (207)	total: 8m 13s	remaining: 11m 33s
# 208:	learn: 1.4395427	test: 2.5621023	best: 2.5621023 (208)	total: 8m 16s	remaining: 11m 30s
# 209:	learn: 1.4365576	test: 2.5607233	best: 2.5607233 (209)	total: 8m 18s	remaining: 11m 28s
# 210:	learn: 1.4310784	test: 2.5554576	best: 2.5554576 (210)	total: 8m 20s	remaining: 11m 25s
# 211:	learn: 1.4181383	test: 2.5405405	best: 2.5405405 (211)	total: 8m 22s	remaining: 11m 23s
# 212:	learn: 1.4162533	test: 2.5392422	best: 2.5392422 (212)	total: 8m 25s	remaining: 11m 20s
# 213:	learn: 1.4120744	test: 2.5361184	best: 2.5361184 (213)	total: 8m 27s	remaining: 11m 18s
# 214:	learn: 1.4087655	test: 2.5335969	best: 2.5335969 (214)	total: 8m 29s	remaining: 11m 15s
# 215:	learn: 1.4038237	test: 2.5304286	best: 2.5304286 (215)	total: 8m 32s	remaining: 11m 13s
# 216:	learn: 1.4003198	test: 2.5281696	best: 2.5281696 (216)	total: 8m 34s	remaining: 11m 10s
# 217:	learn: 1.3958918	test: 2.5251380	best: 2.5251380 (217)	total: 8m 36s	remaining: 11m 8s
# 218:	learn: 1.3902642	test: 2.5210216	best: 2.5210216 (218)	total: 8m 39s	remaining: 11m 6s
# 219:	learn: 1.3875967	test: 2.5193805	best: 2.5193805 (219)	total: 8m 41s	remaining: 11m 3s
# 220:	learn: 1.3825127	test: 2.5157489	best: 2.5157489 (220)	total: 8m 43s	remaining: 11m 1s
# 221:	learn: 1.3786989	test: 2.5132242	best: 2.5132242 (221)	total: 8m 46s	remaining: 10m 58s
# 222:	learn: 1.3745823	test: 2.5104411	best: 2.5104411 (222)	total: 8m 48s	remaining: 10m 56s
# 223:	learn: 1.3662413	test: 2.5044875	best: 2.5044875 (223)	total: 8m 50s	remaining: 10m 54s
# 224:	learn: 1.3619190	test: 2.5015757	best: 2.5015757 (224)	total: 8m 53s	remaining: 10m 51s
# 225:	learn: 1.3578633	test: 2.4991973	best: 2.4991973 (225)	total: 8m 55s	remaining: 10m 49s
# 226:	learn: 1.3559129	test: 2.4975662	best: 2.4975662 (226)	total: 8m 57s	remaining: 10m 46s
# 227:	learn: 1.3493104	test: 2.4932048	best: 2.4932048 (227)	total: 8m 59s	remaining: 10m 44s
# 228:	learn: 1.3470652	test: 2.4912858	best: 2.4912858 (228)	total: 9m 2s	remaining: 10m 41s
# 229:	learn: 1.3438862	test: 2.4893577	best: 2.4893577 (229)	total: 9m 4s	remaining: 10m 39s
# 230:	learn: 1.3408122	test: 2.4866972	best: 2.4866972 (230)	total: 9m 6s	remaining: 10m 36s
# 231:	learn: 1.3362380	test: 2.4841942	best: 2.4841942 (231)	total: 9m 9s	remaining: 10m 34s
# 232:	learn: 1.3312842	test: 2.4812031	best: 2.4812031 (232)	total: 9m 11s	remaining: 10m 32s
# 233:	learn: 1.3266096	test: 2.4770501	best: 2.4770501 (233)	total: 9m 14s	remaining: 10m 30s
# 234:	learn: 1.3198700	test: 2.4712281	best: 2.4712281 (234)	total: 9m 16s	remaining: 10m 27s
# 235:	learn: 1.3163281	test: 2.4692467	best: 2.4692467 (235)	total: 9m 19s	remaining: 10m 25s
# 236:	learn: 1.3130798	test: 2.4672383	best: 2.4672383 (236)	total: 9m 21s	remaining: 10m 23s
# 237:	learn: 1.3085038	test: 2.4649968	best: 2.4649968 (237)	total: 9m 23s	remaining: 10m 20s
# 238:	learn: 1.3004685	test: 2.4595634	best: 2.4595634 (238)	total: 9m 26s	remaining: 10m 18s
# 239:	learn: 1.2967504	test: 2.4580745	best: 2.4580745 (239)	total: 9m 28s	remaining: 10m 16s
# 240:	learn: 1.2945674	test: 2.4563753	best: 2.4563753 (240)	total: 9m 31s	remaining: 10m 13s
# 241:	learn: 1.2909859	test: 2.4538319	best: 2.4538319 (241)	total: 9m 33s	remaining: 10m 11s
# 242:	learn: 1.2802771	test: 2.4467237	best: 2.4467237 (242)	total: 9m 36s	remaining: 10m 9s
# 243:	learn: 1.2682373	test: 2.4362604	best: 2.4362604 (243)	total: 9m 38s	remaining: 10m 7s
# 244:	learn: 1.2643525	test: 2.4341216	best: 2.4341216 (244)	total: 9m 41s	remaining: 10m 4s
# 245:	learn: 1.2610591	test: 2.4320668	best: 2.4320668 (245)	total: 9m 43s	remaining: 10m 2s
# 246:	learn: 1.2582206	test: 2.4300782	best: 2.4300782 (246)	total: 9m 45s	remaining: 9m 59s
# 247:	learn: 1.2540883	test: 2.4260791	best: 2.4260791 (247)	total: 9m 48s	remaining: 9m 57s
# 248:	learn: 1.2490848	test: 2.4223892	best: 2.4223892 (248)	total: 9m 50s	remaining: 9m 55s
# 249:	learn: 1.2459251	test: 2.4205290	best: 2.4205290 (249)	total: 9m 52s	remaining: 9m 52s
# 250:	learn: 1.2415091	test: 2.4171248	best: 2.4171248 (250)	total: 9m 55s	remaining: 9m 50s
# 251:	learn: 1.2377431	test: 2.4142697	best: 2.4142697 (251)	total: 9m 57s	remaining: 9m 48s
# 252:	learn: 1.2331149	test: 2.4110034	best: 2.4110034 (252)	total: 10m	remaining: 9m 45s
# 253:	learn: 1.2268783	test: 2.4074881	best: 2.4074881 (253)	total: 10m 2s	remaining: 9m 43s
# 254:	learn: 1.2249419	test: 2.4056815	best: 2.4056815 (254)	total: 10m 4s	remaining: 9m 41s
# 255:	learn: 1.2228624	test: 2.4048118	best: 2.4048118 (255)	total: 10m 6s	remaining: 9m 38s
# 256:	learn: 1.2180134	test: 2.4001576	best: 2.4001576 (256)	total: 10m 9s	remaining: 9m 36s
# 257:	learn: 1.2155262	test: 2.3981254	best: 2.3981254 (257)	total: 10m 11s	remaining: 9m 33s
# 258:	learn: 1.2125299	test: 2.3957135	best: 2.3957135 (258)	total: 10m 14s	remaining: 9m 31s
# 259:	learn: 1.2088643	test: 2.3925190	best: 2.3925190 (259)	total: 10m 16s	remaining: 9m 28s
# 260:	learn: 1.2061873	test: 2.3912267	best: 2.3912267 (260)	total: 10m 18s	remaining: 9m 26s
# 261:	learn: 1.2039046	test: 2.3893997	best: 2.3893997 (261)	total: 10m 20s	remaining: 9m 23s
# 262:	learn: 1.2001228	test: 2.3878900	best: 2.3878900 (262)	total: 10m 23s	remaining: 9m 21s
# 263:	learn: 1.1955774	test: 2.3844868	best: 2.3844868 (263)	total: 10m 25s	remaining: 9m 19s
# 264:	learn: 1.1924667	test: 2.3830352	best: 2.3830352 (264)	total: 10m 28s	remaining: 9m 16s
# 265:	learn: 1.1895425	test: 2.3812683	best: 2.3812683 (265)	total: 10m 30s	remaining: 9m 14s
# 266:	learn: 1.1848500	test: 2.3784046	best: 2.3784046 (266)	total: 10m 32s	remaining: 9m 12s
# 267:	learn: 1.1805626	test: 2.3763324	best: 2.3763324 (267)	total: 10m 35s	remaining: 9m 9s
# 268:	learn: 1.1730138	test: 2.3700484	best: 2.3700484 (268)	total: 10m 37s	remaining: 9m 7s
# 269:	learn: 1.1679578	test: 2.3661775	best: 2.3661775 (269)	total: 10m 40s	remaining: 9m 5s
# 270:	learn: 1.1658946	test: 2.3651670	best: 2.3651670 (270)	total: 10m 42s	remaining: 9m 2s
# 271:	learn: 1.1612006	test: 2.3612722	best: 2.3612722 (271)	total: 10m 44s	remaining: 9m
# 272:	learn: 1.1590544	test: 2.3597165	best: 2.3597165 (272)	total: 10m 47s	remaining: 8m 58s
# 273:	learn: 1.1565055	test: 2.3578599	best: 2.3578599 (273)	total: 10m 49s	remaining: 8m 55s
# 274:	learn: 1.1538015	test: 2.3553727	best: 2.3553727 (274)	total: 10m 51s	remaining: 8m 53s
# 275:	learn: 1.1463704	test: 2.3497225	best: 2.3497225 (275)	total: 10m 54s	remaining: 8m 50s
# 276:	learn: 1.1440780	test: 2.3485047	best: 2.3485047 (276)	total: 10m 56s	remaining: 8m 48s
# 277:	learn: 1.1419292	test: 2.3473345	best: 2.3473345 (277)	total: 10m 58s	remaining: 8m 45s
# 278:	learn: 1.1404757	test: 2.3461929	best: 2.3461929 (278)	total: 11m	remaining: 8m 43s
# 279:	learn: 1.1384043	test: 2.3441205	best: 2.3441205 (279)	total: 11m 2s	remaining: 8m 40s
# 280:	learn: 1.1366226	test: 2.3425230	best: 2.3425230 (280)	total: 11m 5s	remaining: 8m 38s
# 281:	learn: 1.1346994	test: 2.3404143	best: 2.3404143 (281)	total: 11m 7s	remaining: 8m 35s
# 282:	learn: 1.1316595	test: 2.3385371	best: 2.3385371 (282)	total: 11m 9s	remaining: 8m 33s
# 283:	learn: 1.1286141	test: 2.3364455	best: 2.3364455 (283)	total: 11m 11s	remaining: 8m 31s
# 284:	learn: 1.1264552	test: 2.3351146	best: 2.3351146 (284)	total: 11m 14s	remaining: 8m 28s
# 285:	learn: 1.1242204	test: 2.3345168	best: 2.3345168 (285)	total: 11m 16s	remaining: 8m 26s
# 286:	learn: 1.1206700	test: 2.3319141	best: 2.3319141 (286)	total: 11m 18s	remaining: 8m 23s
# 287:	learn: 1.1177663	test: 2.3297936	best: 2.3297936 (287)	total: 11m 21s	remaining: 8m 21s
# 288:	learn: 1.1165400	test: 2.3289875	best: 2.3289875 (288)	total: 11m 23s	remaining: 8m 18s
# 289:	learn: 1.1138014	test: 2.3265699	best: 2.3265699 (289)	total: 11m 25s	remaining: 8m 16s
# 290:	learn: 1.1112755	test: 2.3247097	best: 2.3247097 (290)	total: 11m 27s	remaining: 8m 13s
# 291:	learn: 1.1092156	test: 2.3233139	best: 2.3233139 (291)	total: 11m 29s	remaining: 8m 11s
# 292:	learn: 1.1062497	test: 2.3207945	best: 2.3207945 (292)	total: 11m 32s	remaining: 8m 9s
# 293:	learn: 1.1046557	test: 2.3191500	best: 2.3191500 (293)	total: 11m 34s	remaining: 8m 6s
# 294:	learn: 1.1028540	test: 2.3178434	best: 2.3178434 (294)	total: 11m 36s	remaining: 8m 4s
# 295:	learn: 1.0988558	test: 2.3152953	best: 2.3152953 (295)	total: 11m 39s	remaining: 8m 1s
# 296:	learn: 1.0961855	test: 2.3137479	best: 2.3137479 (296)	total: 11m 41s	remaining: 7m 59s
# 297:	learn: 1.0935208	test: 2.3123254	best: 2.3123254 (297)	total: 11m 44s	remaining: 7m 57s
# 298:	learn: 1.0895506	test: 2.3103500	best: 2.3103500 (298)	total: 11m 46s	remaining: 7m 54s
# 299:	learn: 1.0853749	test: 2.3079446	best: 2.3079446 (299)	total: 11m 49s	remaining: 7m 52s
# 300:	learn: 1.0816590	test: 2.3056271	best: 2.3056271 (300)	total: 11m 51s	remaining: 7m 50s
# 301:	learn: 1.0791923	test: 2.3038710	best: 2.3038710 (301)	total: 11m 53s	remaining: 7m 48s
# 302:	learn: 1.0779244	test: 2.3030509	best: 2.3030509 (302)	total: 11m 55s	remaining: 7m 45s
# 303:	learn: 1.0761768	test: 2.3020485	best: 2.3020485 (303)	total: 11m 58s	remaining: 7m 43s
# 304:	learn: 1.0751089	test: 2.3015028	best: 2.3015028 (304)	total: 12m	remaining: 7m 40s
# 305:	learn: 1.0717304	test: 2.2992909	best: 2.2992909 (305)	total: 12m 2s	remaining: 7m 38s
# 306:	learn: 1.0691557	test: 2.2980315	best: 2.2980315 (306)	total: 12m 5s	remaining: 7m 35s
# 307:	learn: 1.0648108	test: 2.2950502	best: 2.2950502 (307)	total: 12m 7s	remaining: 7m 33s
# 308:	learn: 1.0607688	test: 2.2916093	best: 2.2916093 (308)	total: 12m 10s	remaining: 7m 31s
# 309:	learn: 1.0578381	test: 2.2898530	best: 2.2898530 (309)	total: 12m 12s	remaining: 7m 28s
# 310:	learn: 1.0547412	test: 2.2876332	best: 2.2876332 (310)	total: 12m 14s	remaining: 7m 26s
# 311:	learn: 1.0522282	test: 2.2851145	best: 2.2851145 (311)	total: 12m 17s	remaining: 7m 24s
# 312:	learn: 1.0495396	test: 2.2833248	best: 2.2833248 (312)	total: 12m 19s	remaining: 7m 21s
# 313:	learn: 1.0466874	test: 2.2806030	best: 2.2806030 (313)	total: 12m 21s	remaining: 7m 19s
# 314:	learn: 1.0427212	test: 2.2776620	best: 2.2776620 (314)	total: 12m 24s	remaining: 7m 17s
# 315:	learn: 1.0404296	test: 2.2762505	best: 2.2762505 (315)	total: 12m 26s	remaining: 7m 14s
# 316:	learn: 1.0382108	test: 2.2748074	best: 2.2748074 (316)	total: 12m 28s	remaining: 7m 12s
# 317:	learn: 1.0358423	test: 2.2733577	best: 2.2733577 (317)	total: 12m 31s	remaining: 7m 10s
# 318:	learn: 1.0343516	test: 2.2724479	best: 2.2724479 (318)	total: 12m 33s	remaining: 7m 7s
# 319:	learn: 1.0307001	test: 2.2711468	best: 2.2711468 (319)	total: 12m 36s	remaining: 7m 5s
# 320:	learn: 1.0294101	test: 2.2696554	best: 2.2696554 (320)	total: 12m 38s	remaining: 7m 2s
# 321:	learn: 1.0255609	test: 2.2669908	best: 2.2669908 (321)	total: 12m 40s	remaining: 7m
# 322:	learn: 1.0213138	test: 2.2653687	best: 2.2653687 (322)	total: 12m 43s	remaining: 6m 58s
# 323:	learn: 1.0183379	test: 2.2634540	best: 2.2634540 (323)	total: 12m 45s	remaining: 6m 56s
# 324:	learn: 1.0163157	test: 2.2623551	best: 2.2623551 (324)	total: 12m 48s	remaining: 6m 53s
# 325:	learn: 1.0139006	test: 2.2604128	best: 2.2604128 (325)	total: 12m 50s	remaining: 6m 51s
# 326:	learn: 1.0121940	test: 2.2589075	best: 2.2589075 (326)	total: 12m 52s	remaining: 6m 48s
# 327:	learn: 1.0106601	test: 2.2576515	best: 2.2576515 (327)	total: 12m 54s	remaining: 6m 46s
# 328:	learn: 1.0085854	test: 2.2559006	best: 2.2559006 (328)	total: 12m 57s	remaining: 6m 43s
# 329:	learn: 1.0063888	test: 2.2544183	best: 2.2544183 (329)	total: 12m 59s	remaining: 6m 41s
# 330:	learn: 1.0047217	test: 2.2535762	best: 2.2535762 (330)	total: 13m 1s	remaining: 6m 39s
# 331:	learn: 1.0030842	test: 2.2521666	best: 2.2521666 (331)	total: 13m 3s	remaining: 6m 36s
# 332:	learn: 1.0013709	test: 2.2505823	best: 2.2505823 (332)	total: 13m 6s	remaining: 6m 34s
# 333:	learn: 0.9995401	test: 2.2494652	best: 2.2494652 (333)	total: 13m 8s	remaining: 6m 31s
# 334:	learn: 0.9960455	test: 2.2477383	best: 2.2477383 (334)	total: 13m 11s	remaining: 6m 29s
# 335:	learn: 0.9935379	test: 2.2457748	best: 2.2457748 (335)	total: 13m 13s	remaining: 6m 27s
# 336:	learn: 0.9903830	test: 2.2435648	best: 2.2435648 (336)	total: 13m 15s	remaining: 6m 24s
# 337:	learn: 0.9881926	test: 2.2421841	best: 2.2421841 (337)	total: 13m 18s	remaining: 6m 22s
# 338:	learn: 0.9845478	test: 2.2391621	best: 2.2391621 (338)	total: 13m 20s	remaining: 6m 20s
# 339:	learn: 0.9819520	test: 2.2363261	best: 2.2363261 (339)	total: 13m 22s	remaining: 6m 17s
# 340:	learn: 0.9799499	test: 2.2349394	best: 2.2349394 (340)	total: 13m 25s	remaining: 6m 15s
# 341:	learn: 0.9779368	test: 2.2336554	best: 2.2336554 (341)	total: 13m 27s	remaining: 6m 13s
# 342:	learn: 0.9752326	test: 2.2321084	best: 2.2321084 (342)	total: 13m 30s	remaining: 6m 10s
# 343:	learn: 0.9743285	test: 2.2315633	best: 2.2315633 (343)	total: 13m 32s	remaining: 6m 8s
# 344:	learn: 0.9727215	test: 2.2298754	best: 2.2298754 (344)	total: 13m 34s	remaining: 6m 5s
# 345:	learn: 0.9702879	test: 2.2284067	best: 2.2284067 (345)	total: 13m 36s	remaining: 6m 3s
# 346:	learn: 0.9670094	test: 2.2262333	best: 2.2262333 (346)	total: 13m 39s	remaining: 6m 1s
# 347:	learn: 0.9650420	test: 2.2252378	best: 2.2252378 (347)	total: 13m 41s	remaining: 5m 58s
# 348:	learn: 0.9637780	test: 2.2248107	best: 2.2248107 (348)	total: 13m 43s	remaining: 5m 56s
# 349:	learn: 0.9614149	test: 2.2229379	best: 2.2229379 (349)	total: 13m 45s	remaining: 5m 53s
# 350:	learn: 0.9582334	test: 2.2205357	best: 2.2205357 (350)	total: 13m 48s	remaining: 5m 51s
# 351:	learn: 0.9550579	test: 2.2188624	best: 2.2188624 (351)	total: 13m 50s	remaining: 5m 49s
# 352:	learn: 0.9519515	test: 2.2165064	best: 2.2165064 (352)	total: 13m 53s	remaining: 5m 47s
# 353:	learn: 0.9470251	test: 2.2126742	best: 2.2126742 (353)	total: 13m 55s	remaining: 5m 44s
# 354:	learn: 0.9442945	test: 2.2102202	best: 2.2102202 (354)	total: 13m 58s	remaining: 5m 42s
# 355:	learn: 0.9429031	test: 2.2093021	best: 2.2093021 (355)	total: 14m	remaining: 5m 40s
# 356:	learn: 0.9413794	test: 2.2092921	best: 2.2092921 (356)	total: 14m 2s	remaining: 5m 37s
# 357:	learn: 0.9397208	test: 2.2083775	best: 2.2083775 (357)	total: 14m 5s	remaining: 5m 35s
# 358:	learn: 0.9376556	test: 2.2070325	best: 2.2070325 (358)	total: 14m 7s	remaining: 5m 32s
# 359:	learn: 0.9363536	test: 2.2059350	best: 2.2059350 (359)	total: 14m 9s	remaining: 5m 30s
# 360:	learn: 0.9347153	test: 2.2044932	best: 2.2044932 (360)	total: 14m 11s	remaining: 5m 27s
# 361:	learn: 0.9103592	test: 2.1768345	best: 2.1768345 (361)	total: 14m 14s	remaining: 5m 25s
# 362:	learn: 0.9074001	test: 2.1760900	best: 2.1760900 (362)	total: 14m 16s	remaining: 5m 23s
# 363:	learn: 0.9059366	test: 2.1756837	best: 2.1756837 (363)	total: 14m 19s	remaining: 5m 20s
# 364:	learn: 0.9053574	test: 2.1756282	best: 2.1756282 (364)	total: 14m 21s	remaining: 5m 18s
# 365:	learn: 0.9031290	test: 2.1738761	best: 2.1738761 (365)	total: 14m 23s	remaining: 5m 16s
# 366:	learn: 0.9011122	test: 2.1712880	best: 2.1712880 (366)	total: 14m 25s	remaining: 5m 13s
# 367:	learn: 0.8910075	test: 2.1603264	best: 2.1603264 (367)	total: 14m 28s	remaining: 5m 11s
# 368:	learn: 0.8896264	test: 2.1595458	best: 2.1595458 (368)	total: 14m 30s	remaining: 5m 8s
# 369:	learn: 0.8885491	test: 2.1595980	best: 2.1595458 (368)	total: 14m 32s	remaining: 5m 6s
# 370:	learn: 0.8869871	test: 2.1590564	best: 2.1590564 (370)	total: 14m 34s	remaining: 5m 4s
# 371:	learn: 0.8842187	test: 2.1564144	best: 2.1564144 (371)	total: 14m 37s	remaining: 5m 1s
# 372:	learn: 0.8830961	test: 2.1557631	best: 2.1557631 (372)	total: 14m 39s	remaining: 4m 59s
# 373:	learn: 0.8819927	test: 2.1548333	best: 2.1548333 (373)	total: 14m 41s	remaining: 4m 57s
# 374:	learn: 0.8795556	test: 2.1522454	best: 2.1522454 (374)	total: 14m 44s	remaining: 4m 54s
# 375:	learn: 0.8782195	test: 2.1515185	best: 2.1515185 (375)	total: 14m 46s	remaining: 4m 52s
# 376:	learn: 0.8767488	test: 2.1507239	best: 2.1507239 (376)	total: 14m 48s	remaining: 4m 49s
# 377:	learn: 0.8750796	test: 2.1489398	best: 2.1489398 (377)	total: 14m 50s	remaining: 4m 47s
# 378:	learn: 0.8734471	test: 2.1479446	best: 2.1479446 (378)	total: 14m 53s	remaining: 4m 45s
# 379:	learn: 0.8724966	test: 2.1473781	best: 2.1473781 (379)	total: 14m 55s	remaining: 4m 42s
# 380:	learn: 0.8676294	test: 2.1440452	best: 2.1440452 (380)	total: 14m 57s	remaining: 4m 40s
# 381:	learn: 0.8637972	test: 2.1417800	best: 2.1417800 (381)	total: 15m	remaining: 4m 38s
# 382:	learn: 0.8610962	test: 2.1401204	best: 2.1401204 (382)	total: 15m 2s	remaining: 4m 35s
# 383:	learn: 0.8596986	test: 2.1396780	best: 2.1396780 (383)	total: 15m 4s	remaining: 4m 33s
# 384:	learn: 0.8587052	test: 2.1390288	best: 2.1390288 (384)	total: 15m 6s	remaining: 4m 30s
# 385:	learn: 0.8570092	test: 2.1374950	best: 2.1374950 (385)	total: 15m 8s	remaining: 4m 28s
# 386:	learn: 0.8558168	test: 2.1369363	best: 2.1369363 (386)	total: 15m 11s	remaining: 4m 26s
# 387:	learn: 0.8542460	test: 2.1364579	best: 2.1364579 (387)	total: 15m 13s	remaining: 4m 23s
# 388:	learn: 0.8527965	test: 2.1348728	best: 2.1348728 (388)	total: 15m 15s	remaining: 4m 21s
# 389:	learn: 0.8498273	test: 2.1328740	best: 2.1328740 (389)	total: 15m 18s	remaining: 4m 19s
# 390:	learn: 0.8481748	test: 2.1329877	best: 2.1328740 (389)	total: 15m 20s	remaining: 4m 16s
# 391:	learn: 0.8476047	test: 2.1328702	best: 2.1328702 (391)	total: 15m 22s	remaining: 4m 14s
# 392:	learn: 0.8447621	test: 2.1309283	best: 2.1309283 (392)	total: 15m 25s	remaining: 4m 11s
# 393:	learn: 0.8438260	test: 2.1302384	best: 2.1302384 (393)	total: 15m 27s	remaining: 4m 9s
# 394:	learn: 0.8400934	test: 2.1273054	best: 2.1273054 (394)	total: 15m 29s	remaining: 4m 7s
# 395:	learn: 0.8393654	test: 2.1271753	best: 2.1271753 (395)	total: 15m 32s	remaining: 4m 4s
# 396:	learn: 0.8384282	test: 2.1267297	best: 2.1267297 (396)	total: 15m 34s	remaining: 4m 2s
# 397:	learn: 0.8352581	test: 2.1246208	best: 2.1246208 (397)	total: 15m 36s	remaining: 4m
# 398:	learn: 0.8326706	test: 2.1225068	best: 2.1225068 (398)	total: 15m 39s	remaining: 3m 57s
# 399:	learn: 0.8313057	test: 2.1217152	best: 2.1217152 (399)	total: 15m 41s	remaining: 3m 55s
# 400:	learn: 0.8294853	test: 2.1207746	best: 2.1207746 (400)	total: 15m 43s	remaining: 3m 53s
# 401:	learn: 0.8274558	test: 2.1199428	best: 2.1199428 (401)	total: 15m 46s	remaining: 3m 50s
# 402:	learn: 0.8263986	test: 2.1190113	best: 2.1190113 (402)	total: 15m 48s	remaining: 3m 48s
# 403:	learn: 0.8250923	test: 2.1184400	best: 2.1184400 (403)	total: 15m 50s	remaining: 3m 45s
# 404:	learn: 0.8238727	test: 2.1176895	best: 2.1176895 (404)	total: 15m 53s	remaining: 3m 43s
# 405:	learn: 0.8228353	test: 2.1166512	best: 2.1166512 (405)	total: 15m 55s	remaining: 3m 41s
# 406:	learn: 0.8216855	test: 2.1156003	best: 2.1156003 (406)	total: 15m 57s	remaining: 3m 38s
# 407:	learn: 0.8203295	test: 2.1149835	best: 2.1149835 (407)	total: 15m 59s	remaining: 3m 36s
# 408:	learn: 0.8196635	test: 2.1146701	best: 2.1146701 (408)	total: 16m 2s	remaining: 3m 34s
# 409:	learn: 0.8181118	test: 2.1130411	best: 2.1130411 (409)	total: 16m 4s	remaining: 3m 31s
# 410:	learn: 0.8160864	test: 2.1117694	best: 2.1117694 (410)	total: 16m 6s	remaining: 3m 29s
# 411:	learn: 0.8140944	test: 2.1107344	best: 2.1107344 (411)	total: 16m 9s	remaining: 3m 27s
# 412:	learn: 0.8119252	test: 2.1089019	best: 2.1089019 (412)	total: 16m 11s	remaining: 3m 24s
# 413:	learn: 0.8093832	test: 2.1075031	best: 2.1075031 (413)	total: 16m 13s	remaining: 3m 22s
# 414:	learn: 0.8086407	test: 2.1069719	best: 2.1069719 (414)	total: 16m 16s	remaining: 3m 19s
# 415:	learn: 0.8077789	test: 2.1062531	best: 2.1062531 (415)	total: 16m 18s	remaining: 3m 17s
# 416:	learn: 0.8065926	test: 2.1051734	best: 2.1051734 (416)	total: 16m 20s	remaining: 3m 15s
# 417:	learn: 0.8052801	test: 2.1043780	best: 2.1043780 (417)	total: 16m 22s	remaining: 3m 12s
# 418:	learn: 0.8043059	test: 2.1034925	best: 2.1034925 (418)	total: 16m 24s	remaining: 3m 10s
# 419:	learn: 0.8032793	test: 2.1027252	best: 2.1027252 (419)	total: 16m 27s	remaining: 3m 8s
# 420:	learn: 0.8022975	test: 2.1017858	best: 2.1017858 (420)	total: 16m 29s	remaining: 3m 5s
# 421:	learn: 0.8012458	test: 2.1012378	best: 2.1012378 (421)	total: 16m 31s	remaining: 3m 3s
# 422:	learn: 0.8002149	test: 2.1010006	best: 2.1010006 (422)	total: 16m 34s	remaining: 3m
# 423:	learn: 0.7990037	test: 2.1003789	best: 2.1003789 (423)	total: 16m 36s	remaining: 2m 58s
# 424:	learn: 0.7981802	test: 2.1001484	best: 2.1001484 (424)	total: 16m 38s	remaining: 2m 56s
# 425:	learn: 0.7950108	test: 2.0985984	best: 2.0985984 (425)	total: 16m 41s	remaining: 2m 53s
# 426:	learn: 0.7933205	test: 2.0971825	best: 2.0971825 (426)	total: 16m 43s	remaining: 2m 51s
# 427:	learn: 0.7915168	test: 2.0955399	best: 2.0955399 (427)	total: 16m 45s	remaining: 2m 49s
# 428:	learn: 0.7901571	test: 2.0948322	best: 2.0948322 (428)	total: 16m 48s	remaining: 2m 46s
# 429:	learn: 0.7876718	test: 2.0935109	best: 2.0935109 (429)	total: 16m 50s	remaining: 2m 44s
# 430:	learn: 0.7857037	test: 2.0913482	best: 2.0913482 (430)	total: 16m 52s	remaining: 2m 42s
# 431:	learn: 0.7810369	test: 2.0895602	best: 2.0895602 (431)	total: 16m 55s	remaining: 2m 39s
# 432:	learn: 0.7795639	test: 2.0891056	best: 2.0891056 (432)	total: 16m 57s	remaining: 2m 37s
# 433:	learn: 0.7775413	test: 2.0877466	best: 2.0877466 (433)	total: 17m	remaining: 2m 35s
# 434:	learn: 0.7757110	test: 2.0867359	best: 2.0867359 (434)	total: 17m 2s	remaining: 2m 32s
# 435:	learn: 0.7740219	test: 2.0861598	best: 2.0861598 (435)	total: 17m 4s	remaining: 2m 30s
# 436:	learn: 0.7732058	test: 2.0862415	best: 2.0861598 (435)	total: 17m 7s	remaining: 2m 28s
# 437:	learn: 0.7722131	test: 2.0855345	best: 2.0855345 (437)	total: 17m 9s	remaining: 2m 25s
# 438:	learn: 0.7708665	test: 2.0842255	best: 2.0842255 (438)	total: 17m 11s	remaining: 2m 23s
# 439:	learn: 0.7691907	test: 2.0828260	best: 2.0828260 (439)	total: 17m 14s	remaining: 2m 21s
# 440:	learn: 0.7679315	test: 2.0830170	best: 2.0828260 (439)	total: 17m 16s	remaining: 2m 18s
# 441:	learn: 0.7660213	test: 2.0810363	best: 2.0810363 (441)	total: 17m 18s	remaining: 2m 16s
# 442:	learn: 0.7647000	test: 2.0803720	best: 2.0803720 (442)	total: 17m 21s	remaining: 2m 13s
# 443:	learn: 0.7636466	test: 2.0797612	best: 2.0797612 (443)	total: 17m 23s	remaining: 2m 11s
# 444:	learn: 0.7620338	test: 2.0777111	best: 2.0777111 (444)	total: 17m 25s	remaining: 2m 9s
# 445:	learn: 0.7612654	test: 2.0775870	best: 2.0775870 (445)	total: 17m 28s	remaining: 2m 6s
# 446:	learn: 0.7595769	test: 2.0763127	best: 2.0763127 (446)	total: 17m 30s	remaining: 2m 4s
# 447:	learn: 0.7579723	test: 2.0755496	best: 2.0755496 (447)	total: 17m 33s	remaining: 2m 2s
# 448:	learn: 0.7563095	test: 2.0732722	best: 2.0732722 (448)	total: 17m 35s	remaining: 1m 59s
# 449:	learn: 0.7554442	test: 2.0727141	best: 2.0727141 (449)	total: 17m 37s	remaining: 1m 57s
# 450:	learn: 0.7545777	test: 2.0727884	best: 2.0727141 (449)	total: 17m 39s	remaining: 1m 55s
# 451:	learn: 0.7537106	test: 2.0725774	best: 2.0725774 (451)	total: 17m 41s	remaining: 1m 52s
# 452:	learn: 0.7526782	test: 2.0718601	best: 2.0718601 (452)	total: 17m 44s	remaining: 1m 50s
# 453:	learn: 0.7509152	test: 2.0702582	best: 2.0702582 (453)	total: 17m 46s	remaining: 1m 48s
# 454:	learn: 0.7492274	test: 2.0691098	best: 2.0691098 (454)	total: 17m 48s	remaining: 1m 45s
# 455:	learn: 0.7483895	test: 2.0685881	best: 2.0685881 (455)	total: 17m 51s	remaining: 1m 43s
# 456:	learn: 0.7471961	test: 2.0676516	best: 2.0676516 (456)	total: 17m 53s	remaining: 1m 41s
# 457:	learn: 0.7463319	test: 2.0671031	best: 2.0671031 (457)	total: 17m 55s	remaining: 1m 38s
# 458:	learn: 0.7403195	test: 2.0593909	best: 2.0593909 (458)	total: 17m 58s	remaining: 1m 36s
# 459:	learn: 0.7394154	test: 2.0586740	best: 2.0586740 (459)	total: 18m	remaining: 1m 33s
# 460:	learn: 0.7391983	test: 2.0587664	best: 2.0586740 (459)	total: 18m 2s	remaining: 1m 31s
# 461:	learn: 0.7382034	test: 2.0581492	best: 2.0581492 (461)	total: 18m 4s	remaining: 1m 29s
# 462:	learn: 0.7373573	test: 2.0571590	best: 2.0571590 (462)	total: 18m 6s	remaining: 1m 26s
# 463:	learn: 0.7363496	test: 2.0564310	best: 2.0564310 (463)	total: 18m 9s	remaining: 1m 24s
# 464:	learn: 0.7356976	test: 2.0561357	best: 2.0561357 (464)	total: 18m 11s	remaining: 1m 22s
# 465:	learn: 0.7334368	test: 2.0543830	best: 2.0543830 (465)	total: 18m 13s	remaining: 1m 19s
# 466:	learn: 0.7328371	test: 2.0540918	best: 2.0540918 (466)	total: 18m 15s	remaining: 1m 17s
# 467:	learn: 0.7319011	test: 2.0535646	best: 2.0535646 (467)	total: 18m 18s	remaining: 1m 15s
# 468:	learn: 0.7304026	test: 2.0524967	best: 2.0524967 (468)	total: 18m 20s	remaining: 1m 12s
# 469:	learn: 0.7293263	test: 2.0521505	best: 2.0521505 (469)	total: 18m 22s	remaining: 1m 10s
# 470:	learn: 0.7275082	test: 2.0505272	best: 2.0505272 (470)	total: 18m 25s	remaining: 1m 8s
# 471:	learn: 0.7264989	test: 2.0498970	best: 2.0498970 (471)	total: 18m 27s	remaining: 1m 5s
# 472:	learn: 0.7257352	test: 2.0497414	best: 2.0497414 (472)	total: 18m 29s	remaining: 1m 3s
# 473:	learn: 0.7245722	test: 2.0481880	best: 2.0481880 (473)	total: 18m 31s	remaining: 1m
# 474:	learn: 0.7234256	test: 2.0478848	best: 2.0478848 (474)	total: 18m 34s	remaining: 58.6s
# 475:	learn: 0.7229714	test: 2.0475310	best: 2.0475310 (475)	total: 18m 36s	remaining: 56.3s
# 476:	learn: 0.7224606	test: 2.0470242	best: 2.0470242 (476)	total: 18m 38s	remaining: 53.9s
# 477:	learn: 0.7216881	test: 2.0468816	best: 2.0468816 (477)	total: 18m 40s	remaining: 51.6s
# 478:	learn: 0.7197344	test: 2.0457021	best: 2.0457021 (478)	total: 18m 43s	remaining: 49.2s
# 479:	learn: 0.7179783	test: 2.0441730	best: 2.0441730 (479)	total: 18m 45s	remaining: 46.9s
# 480:	learn: 0.7169903	test: 2.0431672	best: 2.0431672 (480)	total: 18m 47s	remaining: 44.5s
# 481:	learn: 0.7157770	test: 2.0423760	best: 2.0423760 (481)	total: 18m 50s	remaining: 42.2s
# 482:	learn: 0.7146010	test: 2.0416095	best: 2.0416095 (482)	total: 18m 52s	remaining: 39.9s
# 483:	learn: 0.7139688	test: 2.0418088	best: 2.0416095 (482)	total: 18m 54s	remaining: 37.5s
# 484:	learn: 0.7122053	test: 2.0403638	best: 2.0403638 (484)	total: 18m 56s	remaining: 35.2s
# 485:	learn: 0.7102652	test: 2.0385732	best: 2.0385732 (485)	total: 18m 59s	remaining: 32.8s
# 486:	learn: 0.7091052	test: 2.0379213	best: 2.0379213 (486)	total: 19m 1s	remaining: 30.5s
# 487:	learn: 0.7078029	test: 2.0372864	best: 2.0372864 (487)	total: 19m 4s	remaining: 28.1s
# 488:	learn: 0.7069399	test: 2.0370846	best: 2.0370846 (488)	total: 19m 6s	remaining: 25.8s
# 489:	learn: 0.7063106	test: 2.0364214	best: 2.0364214 (489)	total: 19m 8s	remaining: 23.4s
# 490:	learn: 0.7049623	test: 2.0359821	best: 2.0359821 (490)	total: 19m 10s	remaining: 21.1s
# 491:	learn: 0.7032765	test: 2.0349883	best: 2.0349883 (491)	total: 19m 13s	remaining: 18.8s
# 492:	learn: 0.7002655	test: 2.0326927	best: 2.0326927 (492)	total: 19m 15s	remaining: 16.4s
# 493:	learn: 0.6985038	test: 2.0310590	best: 2.0310590 (493)	total: 19m 18s	remaining: 14.1s
# 494:	learn: 0.6976984	test: 2.0307050	best: 2.0307050 (494)	total: 19m 20s	remaining: 11.7s
# 495:	learn: 0.6967643	test: 2.0302021	best: 2.0302021 (495)	total: 19m 22s	remaining: 9.38s
# 496:	learn: 0.6958499	test: 2.0294522	best: 2.0294522 (496)	total: 19m 24s	remaining: 7.03s
# 497:	learn: 0.6944956	test: 2.0287619	best: 2.0287619 (497)	total: 19m 27s	remaining: 4.69s
# 498:	learn: 0.6939627	test: 2.0282631	best: 2.0282631 (498)	total: 19m 29s	remaining: 2.34s
# 499:	learn: 0.6934770	test: 2.0280911	best: 2.0280911 (499)	total: 19m 31s	remaining: 0us
# bestTest = 2.028091062
# bestIteration = 499
# Training on fold [1/5]
# 0:	learn: 6.9320094	test: 7.0168690	best: 7.0168690 (0)	total: 2.49s	remaining: 20m 40s
# 1:	learn: 7.8337147	test: 7.8498297	best: 7.0168690 (0)	total: 5s	remaining: 20m 46s
# 2:	learn: 7.1235513	test: 7.2121059	best: 7.0168690 (0)	total: 7.47s	remaining: 20m 37s
# 3:	learn: 6.1626250	test: 6.3121680	best: 6.3121680 (3)	total: 10s	remaining: 20m 41s
# 4:	learn: 5.6754240	test: 5.8587925	best: 5.8587925 (4)	total: 12.5s	remaining: 20m 34s
# 5:	learn: 5.4335097	test: 5.6410176	best: 5.6410176 (5)	total: 14.9s	remaining: 20m 29s
# 6:	learn: 5.1063790	test: 5.3404030	best: 5.3404030 (6)	total: 17.5s	remaining: 20m 30s
# 7:	learn: 4.8964533	test: 5.1485814	best: 5.1485814 (7)	total: 20s	remaining: 20m 27s
# 8:	learn: 4.6745553	test: 4.9556017	best: 4.9556017 (8)	total: 22.5s	remaining: 20m 28s
# 9:	learn: 4.4786942	test: 4.7804996	best: 4.7804996 (9)	total: 25s	remaining: 20m 25s
# 10:	learn: 4.2820043	test: 4.6090589	best: 4.6090589 (10)	total: 27.6s	remaining: 20m 27s
# 11:	learn: 4.1845606	test: 4.5219732	best: 4.5219732 (11)	total: 29.9s	remaining: 20m 15s
# 12:	learn: 4.0574973	test: 4.4071241	best: 4.4071241 (12)	total: 32.4s	remaining: 20m 13s
# 13:	learn: 3.8990175	test: 4.2685536	best: 4.2685536 (13)	total: 34.9s	remaining: 20m 12s
# 14:	learn: 3.8409117	test: 4.2207753	best: 4.2207753 (14)	total: 37.3s	remaining: 20m 6s
# 15:	learn: 3.7039732	test: 4.1000252	best: 4.1000252 (15)	total: 39.9s	remaining: 20m 5s
# 16:	learn: 3.5614356	test: 3.9847431	best: 3.9847431 (16)	total: 42.4s	remaining: 20m 5s
# 17:	learn: 3.4422314	test: 3.8839508	best: 3.8839508 (17)	total: 45s	remaining: 20m 3s
# 18:	learn: 3.3447855	test: 3.7992774	best: 3.7992774 (18)	total: 47.4s	remaining: 20m
# 19:	learn: 3.2597742	test: 3.7282055	best: 3.7282055 (19)	total: 49.9s	remaining: 19m 58s
# ...
# 328:	learn: 0.2847293	test: 1.1816904	best: 1.1816904 (328)	total: 12m 30s	remaining: 6m 29s
# 329:	learn: 0.2833812	test: 1.1809314	best: 1.1809314 (329)	total: 12m 32s	remaining: 6m 27s
# 330:	learn: 0.2816988	test: 1.1797933	best: 1.1797933 (330)	total: 12m 34s	remaining: 6m 25s
# 331:	learn: 0.2813855	test: 1.1795726	best: 1.1795726 (331)	total: 12m 36s	remaining: 6m 22s
# 332:	learn: 0.2805539	test: 1.1785755	best: 1.1785755 (332)	total: 12m 38s	remaining: 6m 20s
# 333:	learn: 0.2793482	test: 1.1778185	best: 1.1778185 (333)	total: 12m 40s	remaining: 6m 18s
# 334:	learn: 0.2785242	test: 1.1773010	best: 1.1773010 (334)	total: 12m 43s	remaining: 6m 15s
# 335:	learn: 0.2776400	test: 1.1765364	best: 1.1765364 (335)	total: 12m 45s	remaining: 6m 13s
# 336:	learn: 0.2768073	test: 1.1760166	best: 1.1760166 (336)	total: 12m 47s	remaining: 6m 11s
# 337:	learn: 0.2761296	test: 1.1753434	best: 1.1753434 (337)	total: 12m 49s	remaining: 6m 8s
# 338:	learn: 0.2753585	test: 1.1747874	best: 1.1747874 (338)	total: 12m 51s	remaining: 6m 6s
# 339:	learn: 0.2743704	test: 1.1734797	best: 1.1734797 (339)	total: 12m 54s	remaining: 6m 4s
# 340:	learn: 0.2737646	test: 1.1732226	best: 1.1732226 (340)	total: 12m 56s	remaining: 6m 1s
# 341:	learn: 0.2730156	test: 1.1726133	best: 1.1726133 (341)	total: 12m 58s	remaining: 5m 59s
# 342:	learn: 0.2723294	test: 1.1721066	best: 1.1721066 (342)	total: 13m	remaining: 5m 57s
# 343:	learn: 0.2715723	test: 1.1718814	best: 1.1718814 (343)	total: 13m 2s	remaining: 5m 54s
# 344:	learn: 0.2702489	test: 1.1710401	best: 1.1710401 (344)	total: 13m 4s	remaining: 5m 52s
# 345:	learn: 0.2697321	test: 1.1707387	best: 1.1707387 (345)	total: 13m 7s	remaining: 5m 50s
# 346:	learn: 0.2693894	test: 1.1704753	best: 1.1704753 (346)	total: 13m 9s	remaining: 5m 47s
# 347:	learn: 0.2687178	test: 1.1698983	best: 1.1698983 (347)	total: 13m 11s	remaining: 5m 45s
# 348:	learn: 0.2682468	test: 1.1695234	best: 1.1695234 (348)	total: 13m 13s	remaining: 5m 43s
# 349:	learn: 0.2673392	test: 1.1689542	best: 1.1689542 (349)	total: 13m 15s	remaining: 5m 40s
# 350:	learn: 0.2664371	test: 1.1683453	best: 1.1683453 (350)	total: 13m 17s	remaining: 5m 38s
# 351:	learn: 0.2660292	test: 1.1679849	best: 1.1679849 (351)	total: 13m 19s	remaining: 5m 36s
# 352:	learn: 0.2653219	test: 1.1672740	best: 1.1672740 (352)	total: 13m 21s	remaining: 5m 33s
# 353:	learn: 0.2637076	test: 1.1664453	best: 1.1664453 (353)	total: 13m 24s	remaining: 5m 31s
# 354:	learn: 0.2627447	test: 1.1658020	best: 1.1658020 (354)	total: 13m 26s	remaining: 5m 29s
# 355:	learn: 0.2621079	test: 1.1652700	best: 1.1652700 (355)	total: 13m 28s	remaining: 5m 27s
# 356:	learn: 0.2609926	test: 1.1644024	best: 1.1644024 (356)	total: 13m 30s	remaining: 5m 24s
# 357:	learn: 0.2601904	test: 1.1636690	best: 1.1636690 (357)	total: 13m 32s	remaining: 5m 22s
# 358:	learn: 0.2597905	test: 1.1632550	best: 1.1632550 (358)	total: 13m 35s	remaining: 5m 20s
# 359:	learn: 0.2584706	test: 1.1619571	best: 1.1619571 (359)	total: 13m 37s	remaining: 5m 17s
# 360:	learn: 0.2573945	test: 1.1611444	best: 1.1611444 (360)	total: 13m 39s	remaining: 5m 15s
# 361:	learn: 0.2565525	test: 1.1603267	best: 1.1603267 (361)	total: 13m 41s	remaining: 5m 13s
# 362:	learn: 0.2552317	test: 1.1589253	best: 1.1589253 (362)	total: 13m 43s	remaining: 5m 10s
# 363:	learn: 0.2545981	test: 1.1583047	best: 1.1583047 (363)	total: 13m 45s	remaining: 5m 8s
# 364:	learn: 0.2533019	test: 1.1569721	best: 1.1569721 (364)	total: 13m 48s	remaining: 5m 6s
# 365:	learn: 0.2528801	test: 1.1566923	best: 1.1566923 (365)	total: 13m 50s	remaining: 5m 3s
# 366:	learn: 0.2515675	test: 1.1555570	best: 1.1555570 (366)	total: 13m 52s	remaining: 5m 1s
# 367:	learn: 0.2506626	test: 1.1547937	best: 1.1547937 (367)	total: 13m 54s	remaining: 4m 59s
# 368:	learn: 0.2499611	test: 1.1544112	best: 1.1544112 (368)	total: 13m 56s	remaining: 4m 57s
# 369:	learn: 0.2491805	test: 1.1537376	best: 1.1537376 (369)	total: 13m 59s	remaining: 4m 54s
# 370:	learn: 0.2483363	test: 1.1529374	best: 1.1529374 (370)	total: 14m 1s	remaining: 4m 52s
# 371:	learn: 0.2478985	test: 1.1528503	best: 1.1528503 (371)	total: 14m 3s	remaining: 4m 50s
# 372:	learn: 0.2472497	test: 1.1523090	best: 1.1523090 (372)	total: 14m 5s	remaining: 4m 47s
# 373:	learn: 0.2463832	test: 1.1517788	best: 1.1517788 (373)	total: 14m 7s	remaining: 4m 45s
# 374:	learn: 0.2457795	test: 1.1513968	best: 1.1513968 (374)	total: 14m 9s	remaining: 4m 43s
# 375:	learn: 0.2454618	test: 1.1512090	best: 1.1512090 (375)	total: 14m 11s	remaining: 4m 40s
# 376:	learn: 0.2448186	test: 1.1507313	best: 1.1507313 (376)	total: 14m 14s	remaining: 4m 38s
# 377:	learn: 0.2446413	test: 1.1505100	best: 1.1505100 (377)	total: 14m 16s	remaining: 4m 36s
# 378:	learn: 0.2440684	test: 1.1499635	best: 1.1499635 (378)	total: 14m 18s	remaining: 4m 33s
# 379:	learn: 0.2438446	test: 1.1498187	best: 1.1498187 (379)	total: 14m 20s	remaining: 4m 31s
# 380:	learn: 0.2433192	test: 1.1492433	best: 1.1492433 (380)	total: 14m 22s	remaining: 4m 29s
# 381:	learn: 0.2428670	test: 1.1489462	best: 1.1489462 (381)	total: 14m 24s	remaining: 4m 27s
# 382:	learn: 0.2422332	test: 1.1486565	best: 1.1486565 (382)	total: 14m 26s	remaining: 4m 24s
# 383:	learn: 0.2414361	test: 1.1480030	best: 1.1480030 (383)	total: 14m 28s	remaining: 4m 22s
# 384:	learn: 0.2407589	test: 1.1475831	best: 1.1475831 (384)	total: 14m 30s	remaining: 4m 20s
# 385:	learn: 0.2394389	test: 1.1465749	best: 1.1465749 (385)	total: 14m 33s	remaining: 4m 17s
# 386:	learn: 0.2389089	test: 1.1465729	best: 1.1465729 (386)	total: 14m 35s	remaining: 4m 15s
# 387:	learn: 0.2381170	test: 1.1457980	best: 1.1457980 (387)	total: 14m 37s	remaining: 4m 13s
# 388:	learn: 0.2374258	test: 1.1455266	best: 1.1455266 (388)	total: 14m 39s	remaining: 4m 11s
# 389:	learn: 0.2365896	test: 1.1448854	best: 1.1448854 (389)	total: 14m 42s	remaining: 4m 8s
# 390:	learn: 0.2361789	test: 1.1446763	best: 1.1446763 (390)	total: 14m 44s	remaining: 4m 6s
# 391:	learn: 0.2352606	test: 1.1437643	best: 1.1437643 (391)	total: 14m 46s	remaining: 4m 4s
# 392:	learn: 0.2343054	test: 1.1428875	best: 1.1428875 (392)	total: 14m 48s	remaining: 4m 1s
# 393:	learn: 0.2332462	test: 1.1418859	best: 1.1418859 (393)	total: 14m 50s	remaining: 3m 59s
# 394:	learn: 0.2329187	test: 1.1417435	best: 1.1417435 (394)	total: 14m 52s	remaining: 3m 57s
# 395:	learn: 0.2317438	test: 1.1407660	best: 1.1407660 (395)	total: 14m 55s	remaining: 3m 55s
# 396:	learn: 0.2313014	test: 1.1405466	best: 1.1405466 (396)	total: 14m 57s	remaining: 3m 52s
# 397:	learn: 0.2309438	test: 1.1404017	best: 1.1404017 (397)	total: 14m 59s	remaining: 3m 50s
# 398:	learn: 0.2303888	test: 1.1403241	best: 1.1403241 (398)	total: 15m 1s	remaining: 3m 48s
# 399:	learn: 0.2297718	test: 1.1399410	best: 1.1399410 (399)	total: 15m 3s	remaining: 3m 45s
# 400:	learn: 0.2278717	test: 1.1388667	best: 1.1388667 (400)	total: 15m 6s	remaining: 3m 43s
# 401:	learn: 0.2270871	test: 1.1383362	best: 1.1383362 (401)	total: 15m 8s	remaining: 3m 41s
# 402:	learn: 0.2266032	test: 1.1377867	best: 1.1377867 (402)	total: 15m 10s	remaining: 3m 39s
# 403:	learn: 0.2258783	test: 1.1372962	best: 1.1372962 (403)	total: 15m 12s	remaining: 3m 36s
# 404:	learn: 0.2249212	test: 1.1367410	best: 1.1367410 (404)	total: 15m 14s	remaining: 3m 34s
# 405:	learn: 0.2244982	test: 1.1366155	best: 1.1366155 (405)	total: 15m 16s	remaining: 3m 32s
# 406:	learn: 0.2239492	test: 1.1363121	best: 1.1363121 (406)	total: 15m 18s	remaining: 3m 29s
# 407:	learn: 0.2234007	test: 1.1357753	best: 1.1357753 (407)	total: 15m 20s	remaining: 3m 27s
# 408:	learn: 0.2226942	test: 1.1350998	best: 1.1350998 (408)	total: 15m 23s	remaining: 3m 25s
# 409:	learn: 0.2217807	test: 1.1344856	best: 1.1344856 (409)	total: 15m 25s	remaining: 3m 23s
# 410:	learn: 0.2210714	test: 1.1342219	best: 1.1342219 (410)	total: 15m 27s	remaining: 3m 20s
# 411:	learn: 0.2204834	test: 1.1337858	best: 1.1337858 (411)	total: 15m 29s	remaining: 3m 18s
# 412:	learn: 0.2197808	test: 1.1333410	best: 1.1333410 (412)	total: 15m 32s	remaining: 3m 16s
# 413:	learn: 0.2193219	test: 1.1328378	best: 1.1328378 (413)	total: 15m 34s	remaining: 3m 14s
# 414:	learn: 0.2186916	test: 1.1322418	best: 1.1322418 (414)	total: 15m 36s	remaining: 3m 11s
# 415:	learn: 0.2182606	test: 1.1317446	best: 1.1317446 (415)	total: 15m 38s	remaining: 3m 9s
# 416:	learn: 0.2177788	test: 1.1313919	best: 1.1313919 (416)	total: 15m 40s	remaining: 3m 7s
# 417:	learn: 0.2173585	test: 1.1311517	best: 1.1311517 (417)	total: 15m 42s	remaining: 3m 4s
# 418:	learn: 0.2169308	test: 1.1308375	best: 1.1308375 (418)	total: 15m 44s	remaining: 3m 2s
# 419:	learn: 0.2166636	test: 1.1306172	best: 1.1306172 (419)	total: 15m 46s	remaining: 3m
# 420:	learn: 0.2162467	test: 1.1303130	best: 1.1303130 (420)	total: 15m 48s	remaining: 2m 58s
# 421:	learn: 0.2155289	test: 1.1297180	best: 1.1297180 (421)	total: 15m 51s	remaining: 2m 55s
# 422:	learn: 0.2147897	test: 1.1292287	best: 1.1292287 (422)	total: 15m 53s	remaining: 2m 53s
# 423:	learn: 0.2145039	test: 1.1292452	best: 1.1292287 (422)	total: 15m 55s	remaining: 2m 51s
# 424:	learn: 0.2139782	test: 1.1291219	best: 1.1291219 (424)	total: 15m 57s	remaining: 2m 48s
# 425:	learn: 0.2133733	test: 1.1287369	best: 1.1287369 (425)	total: 15m 59s	remaining: 2m 46s
# 426:	learn: 0.2129236	test: 1.1284448	best: 1.1284448 (426)	total: 16m 2s	remaining: 2m 44s
# 427:	learn: 0.2122342	test: 1.1279540	best: 1.1279540 (427)	total: 16m 4s	remaining: 2m 42s
# 428:	learn: 0.2118900	test: 1.1276619	best: 1.1276619 (428)	total: 16m 6s	remaining: 2m 39s
# 429:	learn: 0.2113853	test: 1.1272862	best: 1.1272862 (429)	total: 16m 8s	remaining: 2m 37s
# 430:	learn: 0.2108954	test: 1.1268198	best: 1.1268198 (430)	total: 16m 10s	remaining: 2m 35s
# 431:	learn: 0.2105109	test: 1.1264758	best: 1.1264758 (431)	total: 16m 12s	remaining: 2m 33s
# 432:	learn: 0.2099480	test: 1.1262389	best: 1.1262389 (432)	total: 16m 14s	remaining: 2m 30s
# 433:	learn: 0.2093781	test: 1.1256244	best: 1.1256244 (433)	total: 16m 17s	remaining: 2m 28s
# 434:	learn: 0.2085034	test: 1.1249315	best: 1.1249315 (434)	total: 16m 19s	remaining: 2m 26s
# 435:	learn: 0.2081523	test: 1.1246955	best: 1.1246955 (435)	total: 16m 21s	remaining: 2m 24s
# 436:	learn: 0.2075766	test: 1.1242342	best: 1.1242342 (436)	total: 16m 23s	remaining: 2m 21s
# 437:	learn: 0.2065322	test: 1.1235249	best: 1.1235249 (437)	total: 16m 25s	remaining: 2m 19s
# 438:	learn: 0.2058495	test: 1.1231088	best: 1.1231088 (438)	total: 16m 27s	remaining: 2m 17s
# 439:	learn: 0.2052286	test: 1.1224771	best: 1.1224771 (439)	total: 16m 30s	remaining: 2m 15s
# 440:	learn: 0.2043606	test: 1.1221388	best: 1.1221388 (440)	total: 16m 32s	remaining: 2m 12s
# 441:	learn: 0.2039451	test: 1.1219116	best: 1.1219116 (441)	total: 16m 34s	remaining: 2m 10s
# 442:	learn: 0.2036528	test: 1.1218906	best: 1.1218906 (442)	total: 16m 36s	remaining: 2m 8s
# 443:	learn: 0.2030311	test: 1.1210861	best: 1.1210861 (443)	total: 16m 38s	remaining: 2m 5s
# 444:	learn: 0.2026929	test: 1.1207219	best: 1.1207219 (444)	total: 16m 40s	remaining: 2m 3s
# 445:	learn: 0.2022115	test: 1.1204081	best: 1.1204081 (445)	total: 16m 42s	remaining: 2m 1s
# 446:	learn: 0.2014282	test: 1.1197369	best: 1.1197369 (446)	total: 16m 45s	remaining: 1m 59s
# 447:	learn: 0.2010359	test: 1.1195066	best: 1.1195066 (447)	total: 16m 47s	remaining: 1m 56s
# 448:	learn: 0.2003703	test: 1.1191678	best: 1.1191678 (448)	total: 16m 49s	remaining: 1m 54s
# 449:	learn: 0.1999302	test: 1.1189387	best: 1.1189387 (449)	total: 16m 51s	remaining: 1m 52s
# 450:	learn: 0.1993969	test: 1.1184491	best: 1.1184491 (450)	total: 16m 53s	remaining: 1m 50s
# 451:	learn: 0.1989326	test: 1.1183441	best: 1.1183441 (451)	total: 16m 56s	remaining: 1m 47s
# 452:	learn: 0.1983933	test: 1.1180169	best: 1.1180169 (452)	total: 16m 58s	remaining: 1m 45s
# 453:	learn: 0.1981481	test: 1.1179492	best: 1.1179492 (453)	total: 17m	remaining: 1m 43s
# 454:	learn: 0.1976929	test: 1.1174062	best: 1.1174062 (454)	total: 17m 2s	remaining: 1m 41s
# 455:	learn: 0.1972655	test: 1.1167647	best: 1.1167647 (455)	total: 17m 4s	remaining: 1m 38s
# 456:	learn: 0.1968550	test: 1.1165009	best: 1.1165009 (456)	total: 17m 6s	remaining: 1m 36s
# 457:	learn: 0.1964328	test: 1.1160911	best: 1.1160911 (457)	total: 17m 8s	remaining: 1m 34s
# 458:	learn: 0.1959631	test: 1.1156252	best: 1.1156252 (458)	total: 17m 10s	remaining: 1m 32s
# 459:	learn: 0.1956428	test: 1.1153784	best: 1.1153784 (459)	total: 17m 12s	remaining: 1m 29s
# 460:	learn: 0.1948283	test: 1.1148921	best: 1.1148921 (460)	total: 17m 15s	remaining: 1m 27s
# 461:	learn: 0.1946052	test: 1.1147103	best: 1.1147103 (461)	total: 17m 17s	remaining: 1m 25s
# 462:	learn: 0.1939298	test: 1.1141309	best: 1.1141309 (462)	total: 17m 19s	remaining: 1m 23s
# 463:	learn: 0.1934970	test: 1.1137513	best: 1.1137513 (463)	total: 17m 21s	remaining: 1m 20s
# 464:	learn: 0.1931333	test: 1.1134441	best: 1.1134441 (464)	total: 17m 23s	remaining: 1m 18s
# 465:	learn: 0.1927432	test: 1.1131283	best: 1.1131283 (465)	total: 17m 25s	remaining: 1m 16s
# 466:	learn: 0.1923240	test: 1.1130384	best: 1.1130384 (466)	total: 17m 28s	remaining: 1m 14s
# 467:	learn: 0.1920981	test: 1.1127659	best: 1.1127659 (467)	total: 17m 30s	remaining: 1m 11s
# 468:	learn: 0.1917739	test: 1.1124796	best: 1.1124796 (468)	total: 17m 32s	remaining: 1m 9s
# 469:	learn: 0.1913950	test: 1.1121242	best: 1.1121242 (469)	total: 17m 34s	remaining: 1m 7s
# 470:	learn: 0.1907743	test: 1.1117917	best: 1.1117917 (470)	total: 17m 36s	remaining: 1m 5s
# 471:	learn: 0.1903993	test: 1.1116250	best: 1.1116250 (471)	total: 17m 38s	remaining: 1m 2s
# 472:	learn: 0.1900611	test: 1.1115687	best: 1.1115687 (472)	total: 17m 40s	remaining: 1m
# 473:	learn: 0.1896358	test: 1.1111864	best: 1.1111864 (473)	total: 17m 42s	remaining: 58.3s
# 474:	learn: 0.1894560	test: 1.1110461	best: 1.1110461 (474)	total: 17m 45s	remaining: 56.1s
# 475:	learn: 0.1887485	test: 1.1104828	best: 1.1104828 (475)	total: 17m 47s	remaining: 53.8s
# 476:	learn: 0.1879871	test: 1.1102136	best: 1.1102136 (476)	total: 17m 49s	remaining: 51.6s
# 477:	learn: 0.1874787	test: 1.1095922	best: 1.1095922 (477)	total: 17m 51s	remaining: 49.3s
# 478:	learn: 0.1870977	test: 1.1093776	best: 1.1093776 (478)	total: 17m 54s	remaining: 47.1s
# 479:	learn: 0.1866997	test: 1.1089616	best: 1.1089616 (479)	total: 17m 56s	remaining: 44.8s
# 480:	learn: 0.1861809	test: 1.1088406	best: 1.1088406 (480)	total: 17m 58s	remaining: 42.6s
# 481:	learn: 0.1857364	test: 1.1085112	best: 1.1085112 (481)	total: 18m	remaining: 40.4s
# 482:	learn: 0.1852148	test: 1.1080967	best: 1.1080967 (482)	total: 18m 2s	remaining: 38.1s
# 483:	learn: 0.1847286	test: 1.1074418	best: 1.1074418 (483)	total: 18m 4s	remaining: 35.9s
# 484:	learn: 0.1841766	test: 1.1069324	best: 1.1069324 (484)	total: 18m 7s	remaining: 33.6s
# 485:	learn: 0.1838336	test: 1.1066156	best: 1.1066156 (485)	total: 18m 9s	remaining: 31.4s
# 486:	learn: 0.1828199	test: 1.1058533	best: 1.1058533 (486)	total: 18m 11s	remaining: 29.1s
# 487:	learn: 0.1821066	test: 1.1050368	best: 1.1050368 (487)	total: 18m 13s	remaining: 26.9s
# 488:	learn: 0.1817990	test: 1.1046874	best: 1.1046874 (488)	total: 18m 15s	remaining: 24.6s
# 489:	learn: 0.1813775	test: 1.1041712	best: 1.1041712 (489)	total: 18m 18s	remaining: 22.4s
# 490:	learn: 0.1807248	test: 1.1034553	best: 1.1034553 (490)	total: 18m 20s	remaining: 20.2s
# 491:	learn: 0.1804212	test: 1.1031602	best: 1.1031602 (491)	total: 18m 22s	remaining: 17.9s
# 492:	learn: 0.1798699	test: 1.1026202	best: 1.1026202 (492)	total: 18m 24s	remaining: 15.7s
# 493:	learn: 0.1796861	test: 1.1024960	best: 1.1024960 (493)	total: 18m 26s	remaining: 13.4s
# 494:	learn: 0.1793079	test: 1.1023837	best: 1.1023837 (494)	total: 18m 28s	remaining: 11.2s
# 495:	learn: 0.1787877	test: 1.1019885	best: 1.1019885 (495)	total: 18m 30s	remaining: 8.96s
# 496:	learn: 0.1783422	test: 1.1013756	best: 1.1013756 (496)	total: 18m 33s	remaining: 6.72s
# 497:	learn: 0.1779064	test: 1.1009192	best: 1.1009192 (497)	total: 18m 35s	remaining: 4.48s
# 498:	learn: 0.1776537	test: 1.1006985	best: 1.1006985 (498)	total: 18m 37s	remaining: 2.24s
# 499:	learn: 0.1774016	test: 1.1004739	best: 1.1004739 (499)	total: 18m 39s	remaining: 0us
# bestTest = 1.100473913
# bestIteration = 499

# %% [markdown]
# Было обучено 5 моделей градиентного бустинга. Давайте посчитаем weighted f1 score для каждой модели. Используем каждый из 5 фолдов для оценки метрики. Далее посмотрим на среднее и минимальное значение метрики для каждой из модели.

# %%
n_test = int(.2 * df_copy.shape[0])

models = scores[1]
models_f1 = {key: [] for key in range(5)}

for i in range(5):
    x_test = df_copy.drop(['category_id'], axis = 1)[i*n_test : (i+1) * n_test]
    y_test= df_copy['category_id'][i * n_test : (i+1) * n_test]

    for i in range(5):
        predictions = [j.argmax() for j in models[i].predict(x_test)]
        models_f1[i].append(f1_score(y_test, predictions, average='weighted'))

models_f1_mean = {k: mean(v) for k,v in models_f1.items()}
models_f1_min = {k: min(v) for k,v in models_f1.items()}

# %%
models_f1_min
# Out:
# {0: 0.7385642168714862,
#  1: 0.7939797319860074,
#  2: 0.7931506359338611,
#  3: 0.7901515808233524,
#  4: 0.7787363651773512}

# %% [markdown]
# Лучший weighted_f1_score ≈ 0.79. Для финального предикта было решено взять модель с **лучшим** значением метрик и функции ошибки - модель с индексом [1].

# %% [markdown]
# ### Финальный инференс

# %%
test_df = pd.read_parquet('KE_internship_2023/test.parquet')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16860 entries, 1 to 24995
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_id   16860 non-null  int64
#  1   sale         16860 non-null  bool
#  2   shop_id      16860 non-null  int64
#  3   shop_title   16860 non-null  object
#  4   rating       16860 non-null  float64
#  5   text_fields  16860 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(2)
# memory usage: 806.8+ KB

# %%
product_title, shop_title = parse_text(test_df)

# Формирование датафрейма

test_df = test_df.drop(['sale', 'shop_id', 'rating', 'text_fields'], axis = 1)

test_df['shop_title'] = shop_title
test_df['product_title'] = product_title
test_df = test_df.reindex(range(len(test_df)),method='ffill')
# Ой, строчка ниже сломала тип данных в product_id
test_df = pd.DataFrame.dropna(test_df)

test_df.head()
# Out:
#    product_id    shop_title                                      product_title
# 1   1997646.0  di-di market  стекло пленка керамик матовое honor 50 lite 10...
# 2    927375.0   visionstore  проводные наушники с микрофоном jack 3.5, ios,...
# 3   1921513.0      fornails  декоративная табличка "правила кухни", подстав...
# 4   1668662.0     моя кухня  подставка под ложку керамическая, подложка "кл...
# 5   1467778.0    style icon     футболка женская с принтом, премиальный хлопок

# %%
model = AutoModel.from_pretrained("cointegrated/rubert-tiny2")
model.cuda()

# Шафл 
test_df = test_df.sample(frac=1).reset_index(drop=True)
test_df = test_df.reindex(range(len(test_df)),method='ffill')

# Генерация эмбеддингов
product_title, shop_title = text2colums(test_df)

# Фикс типов данных 
test_df = test_df.astype({'product_id': 'int64'})

test_df_copy = test_df.drop(['product_title', 'shop_title'], axis = 1)
test_df_copy = pd.concat([test_df_copy, product_title, shop_title], axis=1)
# Out:
# Some weights of the model checkpoint at cointegrated/rubert-tiny2 were not used when initializing BertModel: ['cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
test_df.head()
# Out:
#    product_id       shop_title  \
# 0      876120       magichobby
# 1     1461170       happy room
# 2     1767349  smile of milady
# 3      798579  outside the box
# 4      433998            лайма
#
#                                        product_title
# 0  пряжа gazzal jeans 58% хлопок 42% акрил 50г 17...
# 1                         коробка складная картонная
# 2                          тапочки комнатные женские
# 3  печь и ложка для плавки сургуча, 3 цвета / сур...
# 4  насадка моп для швабры самоотжимной "бабочка" ...

# %%
final_model = models[1]
final_predictions = [j.argmax() for j in final_model.predict(test_df_copy)]

# %%
final_names = pd.Series([categ_dict[i] for i in final_predictions], name = "predicted_name")
present = pd.concat([test_df['product_title'],final_names], axis = 1)
present.head()
# Out:
#                                        product_title  \
# 0  пряжа gazzal jeans 58% хлопок 42% акрил 50г 17...
# 1                         коробка складная картонная
# 2                          тапочки комнатные женские
# 3  печь и ложка для плавки сургуча, 3 цвета / сур...
# 4  насадка моп для швабры самоотжимной "бабочка" ...
#
#                                       predicted_name
# 0  Все категории->Хобби и творчество->Рукоделие->...
# 1  Все категории->Товары для дома->Товары для пра...
# 2  Все категории->Обувь->Женская обувь->Домашняя ...
# 3  Все категории->Хобби и творчество->Рукоделие->...
# 4  Все категории->Товары для дома->Хозяйственные ...

# %%
print(present['product_title'][2], present["predicted_name"][2])
# Out:
# тапочки комнатные женские Все категории->Обувь->Женская обувь->Домашняя обувь

# %%
print(present['product_title'][4], present["predicted_name"][4])
# Out:
# насадка моп для швабры самоотжимной "бабочка" 603607, спонж/микрофибра 26 см, на липучке, любаша, 603608 Все категории->Товары для дома->Хозяйственные товары->Инвентарь для уборки->Швабры и аксессуары->Швабры

# %% [markdown]
# Как видно из ячеек выше - на первый взгляд наша модель выдаёт адекватные предикты.

# %%
final_id = pd.Series([new_to_old_dict[i] for i in final_predictions], name = "predicted_category_id ")
for_submission = pd.concat([test_df['product_id'],final_id], axis = 1)
for_submission.to_parquet(path = 'result.parquet')

# %%
for_submission.head()
# Out:
#    product_id  predicted_category_id
# 0      876120                    2754
# 1     1461170                   11757
# 2     1767349                   13263
# 3      798579                    2775
# 4      433998                   14874

# %% [markdown]
# ### Спасибо большое KE за интересное задание!
